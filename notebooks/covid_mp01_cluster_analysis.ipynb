# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from shapely.geometry import Point
import geopandas as gpd
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import math
import geopy.distance
from datetime import datetime
from tqdm.notebook import tqdm
import glob
import json
from fuzzywuzzy import fuzz, process

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-bb7669edf53e> in <module>
#       3 import matplotlib.pyplot as plt
#       4 import plotly.express as px
# ----> 5 from shapely.geometry import Point
#       6 import geopandas as gpd
#       7 import folium
#
# ModuleNotFoundError: No module named 'shapely'

# %% [markdown]
# ## Read in Hub-Violations and Clusters DataFrames (geocodio versions)

# %%
hub_covid_violations_df = pd.read_csv('../data/hub_covid_violations.csv')

# %%
hub_covid_violations_df.head()

# %%
geocodio_df = pd.read_csv('../data/geocodio_input_df_geocodio_d5d27c584d4aa85e57bb523066377b276f89cac3.csv')

# %%
geocodio_df.head()

# %%
hub_geocodio = hub_covid_violations_df.join(geocodio_df, rsuffix='_geo')

# %%
hub_geocodio.columns

# %%
hub_geocodio = hub_geocodio.drop(['Latitude', 'Longitude', 'Unit Type', 
                                  'Unit Number', 'Country', 'Source', 'Unnamed: 0'], axis=1)

# %%
hub_geocodio.columns = ['Request #', 'Status', 'Date / Time Opened', 'Date / Time Closed',
       'Contact Type', 'State Issue', 'Closed When Created', 'Address', 'City',
       'Council District', 'ZIP', 'Mapped Location', 'Address_geo', 'City_geo', 'ZIP_geo', 'state',
       'Latitude', 'Longitude', 'Accuracy Score', 'Accuracy Type',
       'Number', 'Street', 'City.1', 'State', 'County', 'Zip']

# %%
hub_geocodio.T

# %%
clusters = pd.read_csv('../data/clusters_corrected-Sheet1-2_geocodio_d08379641999d429faecf949b19c4c6f08c2732c.csv')

# %%
clusters.head()
# Out:
#                             Cluster Name                 Street       City  \
# 0                     Vanderbilt Parties                    NaN        NaN
# 1               Event at Clementine Hall  4710 Charlotte Avenue  Nashville
# 2                      Religious Retreat                    NaN        NaN
# 3    The Health Center at Richland Place   504 Elmington Avenue  Nashville
# 4  Trevecca Center for Rehab and Healing  329 Murfreesboro Pike  Nashville
#
#   State     Facility Type Cluster Start Date  # Cases  Latitude_wrong  \
# 0    TN  Social Gathering            3/11/20       49       36.125891
# 1    TN  Social Gathering            3/14/20       23       36.152444
# 2    TN  Social Gathering            3/25/20       18             NaN
# 3    TN              LTCF             4/3/20       47       36.128750
# 4    TN              LTCF             4/4/20      102       36.144562
#
#   Longitude_wrong   Latitude  ...  Number           Street.1 Unit Type  \
# 0      -86.822863  35.858564  ...     NaN                NaN       NaN
# 1      -86.846772  36.152300  ...    4710      Charlotte Ave       NaN
# 2             NaN  35.858564  ...     NaN                NaN       NaN
# 3      -86.819533  36.128791  ...     504      Elmington Ave       NaN
# 4      -86.756749  36.144764  ...     329  Murfreesboro Pike       NaN
#
#   Unit Number     City.1  State.1           County      Zip Country  \
# 0         NaN        NaN       TN              NaN      NaN      US
# 1         NaN  Nashville       TN  Davidson County  37209.0      US
# 2         NaN        NaN       TN              NaN      NaN      US
# 3         NaN  Nashville       TN  Davidson County  37205.0      US
# 4         NaN  Nashville       TN  Davidson County  37210.0      US
#
#                                           Source
# 0                               US Census Bureau
# 1  TIGER/Line® dataset from the US Census Bureau
# 2                               US Census Bureau
# 3  TIGER/Line® dataset from the US Census Bureau
# 4                              City of Nashville
#
# [5 rows x 23 columns]

# %%
clusters = clusters.drop([
    'Latitude_wrong', 'Longitude_wrong', 'Number', 'Street.1', 'Unit Type', 'Unit Number', 
    'City.1', 'State.1', 'Country', 'Source'
], axis=1)

# %%
clusters.head()
# Out:
#                             Cluster Name                 Street       City  \
# 0                     Vanderbilt Parties                    NaN        NaN
# 1               Event at Clementine Hall  4710 Charlotte Avenue  Nashville
# 2                      Religious Retreat                    NaN        NaN
# 3    The Health Center at Richland Place   504 Elmington Avenue  Nashville
# 4  Trevecca Center for Rehab and Healing  329 Murfreesboro Pike  Nashville
#
#   State     Facility Type Cluster Start Date  # Cases   Latitude  Longitude  \
# 0    TN  Social Gathering            3/11/20       49  35.858564 -86.349357
# 1    TN  Social Gathering            3/14/20       23  36.152300 -86.843597
# 2    TN  Social Gathering            3/25/20       18  35.858564 -86.349357
# 3    TN              LTCF             4/3/20       47  36.128791 -86.818522
# 4    TN              LTCF             4/4/20      102  36.144764 -86.755659
#
#    Accuracy Score        Accuracy Type           County      Zip
# 0             1.0                state              NaN      NaN
# 1             1.0  range_interpolation  Davidson County  37209.0
# 2             1.0                state              NaN      NaN
# 3             1.0  range_interpolation  Davidson County  37205.0
# 4             1.0              rooftop  Davidson County  37210.0

# %%
clusters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cluster Name        62 non-null     object
#  1   Street              51 non-null     object
#  2   City                51 non-null     object
#  3   State               56 non-null     object
#  4   Facility Type       62 non-null     object
#  5   Cluster Start Date  62 non-null     object
#  6   # Cases             62 non-null     int64
#  7   Latitude            62 non-null     float64
#  8   Longitude           62 non-null     float64
#  9   Accuracy Score      62 non-null     float64
#  10  Accuracy Type       56 non-null     object
#  11  County              51 non-null     object
#  12  Zip                 51 non-null     float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 6.4+ KB

# %%
clusters['Facility Type'].value_counts().sort_values(ascending=False)
# Out:
# LTCF                     20
# Congregate Living         8
# Bar                       6
# Social Gathering          6
# Correctional Facility     6
# Construction              5
# Other                     3
# Commercial-Warehouse      2
# Gym                       1
# Restaurant                1
# Church                    1
# School                    1
# Office                    1
# College / University      1
# Name: Facility Type, dtype: int64

# %%
cluster_info = clusters.groupby(['Facility Type'])['# Cases'].agg(['nunique', 'sum', 'mean'])
cluster_info
# Out:
#                        nunique  sum        mean
# Facility Type
# Bar                          5  109   18.166667
# Church                       1   10   10.000000
# College / University         1   10   10.000000
# Commercial-Warehouse         2  302  151.000000
# Congregate Living            8  464   58.000000
# Construction                 5  185   37.000000
# Correctional Facility        6  557   92.833333
# Gym                          1   14   14.000000
# LTCF                        17  902   45.100000
# Office                       1   18   18.000000
# Other                        3   55   18.333333
# Restaurant                   1   19   19.000000
# School                       1   19   19.000000
# Social Gathering             6  129   21.500000

# %%
clusters_by_type = pd.read_csv('../data/clusters_by_type.csv')

# %%
clusters_by_type.head()
# Out:
#            Cluster Type  Number of Clusters
# 0                   Bar                   7
# 1                Church                   2
# 2  College / University                   5
# 3  Commercial-Warehouse                  12
# 4     Congregate Living                  13

# %% [markdown]
# ## Merge Clusters and Violations DataFrames
# ### Using coordinates - best match is 3, but currently rounding is deactivated.

# %%
clusters_violations = clusters[clusters['Latitude'].notna()].merge(
    hub_geocodio, 
    on=['Latitude', 'Longitude'], 
    how='inner',
    suffixes=['_clusters', '_violations']
)

# %%
clusters_violations['Cluster Name'].value_counts()
# Out:
# Kid Rock's Big Ass Honky Tonk                    47
# Tootsie's                                        27
# Winner's                                         27
# Dogwood                                          24
# Event at Clementine Hall                         20
# Dawghouse Saloon                                  9
# Montgomery Bell Academy job site                  8
# Tyson Foods                                       6
# Hermitage Hall                                    6
# Miss Kelli's                                      6
# Good Samaritan Health & Healing                   6
# Life Care Center Old Hickory Village              5
# Bethany Center for Rehab and Healing              4
# Link Systems Electric                             4
# The Opal at Music City                            3
# Lois DeBerry Special Needs Facility               3
# Nashville Rescue Mission - Women's Campus         3
# Riverbend Max Security Prison-2                   3
# Debra Johnson Rehab/TN Prison for Women           3
# Creekside Center for Rehab and Healing            3
# Rescue Mission-Fairgrounds                        3
# Cargill                                           2
# Grand Hyatt Hotel (Power Design Inc) job site     2
# One Stone Church Service                          2
# Tennessee Titans                                  1
# Trevecca Center for Rehab and Healing             1
# Lakeshore Meadows                                 1
# Belmont Village of Green Hills                    1
# Metro Water Services                              1
# Ahava / Grace Healthcare of White's Creek         1
# Green Hills Center for Rehab and Healing          1
# Nashville Center for Rehab and Healing            1
# Standing Tall Music City                          1
# Loser's                                           1
# Nashville Center for Rehab and Healing (2)        1
# Name: Cluster Name, dtype: int64

# %%
clusters_violations.columns
# Out:
# Index(['Cluster Name', 'Street_clusters', 'City_clusters', 'State_clusters',
#        'Facility Type', 'Cluster Start Date', '# Cases', 'Latitude',
#        'Longitude', 'Accuracy Score_clusters', 'Accuracy Type_clusters',
#        'County_clusters', 'Zip_clusters', 'Request #', 'Status',
#        'Date / Time Opened', 'Date / Time Closed', 'Contact Type',
#        'State Issue', 'Closed When Created', 'Address', 'City_violations',
#        'Council District', 'ZIP', 'Mapped Location', 'Address_geo', 'City_geo',
#        'ZIP_geo', 'state', 'Accuracy Score_violations',
#        'Accuracy Type_violations', 'Number', 'Street_violations', 'City.1',
#        'State_violations', 'County_violations', 'Zip_violations'],
#       dtype='object')

# %%
clusters_violations[clusters_violations['Cluster Name'] == "Kid Rock's Big Ass Honky Tonk"]['Street_violations'].value_counts()
# Out:
# Broadway    47
# Name: Street_violations, dtype: int64

# %%
hub_geocodio[hub_geocodio['Accuracy Score']>.9]
# Out:
#        Request #  Status   Date / Time Opened   Date / Time Closed  \
# 0         346122  Closed  2020-04-15 11:33:26  2020-04-16 14:55:01
# 1         339374  Closed  2020-04-04 18:13:59  2020-04-09 13:07:22
# 2         343513  Closed  2020-04-10 10:40:08  2020-04-14 19:39:09
# 3         442996  Closed  2020-08-12 02:05:29  2020-08-12 16:03:35
# 5         407667  Closed  2020-07-04 19:59:51  2020-07-06 17:55:19
# ...          ...     ...                  ...                  ...
# 11626     492673  Closed  2020-11-01 01:52:56  2020-11-02 16:09:09
# 11627     493369  Closed  2020-11-02 17:41:20  2020-11-03 15:46:04
# 11628     493733  Closed  2020-11-02 20:43:33  2020-11-03 15:51:51
# 11629     492999  Closed  2020-11-02 14:36:22  2020-11-02 16:15:55
# 11630     493074  Closed  2020-11-02 15:15:54  2020-11-02 16:16:19
#
#       Contact Type  State Issue  Closed When Created              Address  \
# 0              NaN        False                False        928 6th Ave S
# 1              NaN        False                False     500 Gallatin Ave
# 2              NaN        False                False  5720 Crossings Blvd
# 3              NaN        False                False        7689 Hwy 70 S
# 5              NaN        False                False         945 Allen Rd
# ...            ...          ...                  ...                  ...
# 11626          NaN        False                False  7102 Charlotte Pike
# 11627          NaN        False                False   305 Manchester Ave
# 11628          NaN        False                False      2801 Foster Ave
# 11629          NaN        False                False          8080 TN-100
# 11630          NaN        False                False        1400 Adams St
#
#             City  Council District  ...   Latitude  Longitude Accuracy Score  \
# 0      NASHVILLE              17.0  ...  36.148719 -86.772077            1.0
# 1      NASHVILLE               5.0  ...  36.181520 -86.749629            1.0
# 2            NaN               NaN  ...  36.044155 -86.647169            1.0
# 3      NASHVILLE              22.0  ...  36.081001 -86.956301            1.0
# 5      NASHVILLE              15.0  ...  36.150484 -86.665820            1.0
# ...          ...               ...  ...        ...        ...            ...
# 11626  NASHVILLE              35.0  ...  36.128622 -86.906774            1.0
# 11627  NASHVILLE               6.0  ...  36.186782 -86.735788            1.0
# 11628  NASHVILLE              16.0  ...  36.113989 -86.743415            1.0
# 11629  NASHVILLE              35.0  ...  36.045024 -86.953730            1.0
# 11630  NASHVILLE              19.0  ...  36.181619 -86.784214            1.0
#
#              Accuracy Type  Number          Street     City.1  State  \
# 0                  rooftop     928       6th Ave S  Nashville     TN
# 1                  rooftop     500    Gallatin Ave  Nashville     TN
# 2      range_interpolation    5720  Crossings Blvd    Antioch     TN
# 3      range_interpolation    7689        Hwy 70 S  Nashville     TN
# 5                  rooftop     945        Allen Rd  Nashville     TN
# ...                    ...     ...             ...        ...    ...
# 11626  range_interpolation    7102  Charlotte Pike  Nashville     TN
# 11627              rooftop     305  Manchester Ave  Nashville     TN
# 11628  range_interpolation    2801      Foster Ave  Nashville     TN
# 11629  range_interpolation    8080         Hwy 100  Nashville     TN
# 11630              rooftop    1400        Adams St  Nashville     TN
#
#                 County    Zip
# 0      Davidson County  37203
# 1      Davidson County  37206
# 2      Davidson County  37013
# 3      Davidson County  37221
# 5      Davidson County  37214
# ...                ...    ...
# 11626  Davidson County  37209
# 11627  Davidson County  37206
# 11628  Davidson County  37210
# 11629  Davidson County  37221
# 11630  Davidson County  37208
#
# [9978 rows x 26 columns]

# %% [markdown]
# ### Create DataFrame of matching addresses, using FuzzyWuzzy

# %%
clusters_clean = clusters[clusters['Street'].notna()]

# %%
def fuzzy_merge(df_1, df_2, key1, key2, threshold=95, limit=2):
    """
    :param df_1: the left table to join
    :param df_2: the right table to join
    :param key1: key column of the left table
    :param key2: key column of the right table
    :param threshold: how close the matches should be to return a match, based on Levenshtein distance
    :param limit: the amount of matches that will get returned, these are sorted high to low
    :return: dataframe with boths keys and matches
    """
    s = df_2[key2].tolist()

    m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))    
    df_1['matches'] = m

    m2 = df_1['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    df_1['matches'] = m2

    return df_1

# %%
clusters_violations_fuzzy = fuzzy_merge(clusters_clean, hub_geocodio, 'Street', 'Address', limit=1)
# Out:
# <ipython-input-26-d8aa589ec244>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['matches'] = m
# <ipython-input-26-d8aa589ec244>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['matches'] = m2

# %%
clusters_violations_fuzzy.T
# Out:
#                                           1   \
# Cluster Name        Event at Clementine Hall
# Street                 4710 Charlotte Avenue
# City                               Nashville
# State                                     TN
# Facility Type               Social Gathering
# Cluster Start Date                   3/14/20
# # Cases                                   23
# Latitude                             36.1523
# Longitude                           -86.8436
# Accuracy Score                             1
# Accuracy Type            range_interpolation
# County                       Davidson County
# Zip                                    37209
# matches
#
#                                                      3   \
# Cluster Name        The Health Center at Richland Place
# Street                             504 Elmington Avenue
# City                                          Nashville
# State                                                TN
# Facility Type                                      LTCF
# Cluster Start Date                               4/3/20
# # Cases                                              47
# Latitude                                        36.1288
# Longitude                                      -86.8185
# Accuracy Score                                        1
# Accuracy Type                       range_interpolation
# County                                  Davidson County
# Zip                                               37205
# matches
#
#                                                        4   \
# Cluster Name        Trevecca Center for Rehab and Healing
# Street                              329 Murfreesboro Pike
# City                                            Nashville
# State                                                  TN
# Facility Type                                        LTCF
# Cluster Start Date                                 4/4/20
# # Cases                                               102
# Latitude                                          36.1448
# Longitude                                        -86.7557
# Accuracy Score                                          1
# Accuracy Type                                     rooftop
# County                                    Davidson County
# Zip                                                 37210
# matches                             329 Murfreesboro Pike
#
#                                        5   \
# Cluster Name                  Tyson Foods
# Street              201 Cartwright Street
# City                       Goodlettsville
# State                                  TN
# Facility Type        Commercial-Warehouse
# Cluster Start Date                 4/6/20
# # Cases                               280
# Latitude                          36.3313
# Longitude                        -86.7108
# Accuracy Score                          1
# Accuracy Type                     rooftop
# County                    Davidson County
# Zip                                 37072
# matches
#
#                                                         6   \
# Cluster Name        Nashville Center for Rehab and Healing
# Street                                832 Wedgewood Avenue
# City                                             Nashville
# State                                                   TN
# Facility Type                                         LTCF
# Cluster Start Date                                  4/8/20
# # Cases                                                 12
# Latitude                                           36.1348
# Longitude                                          -86.782
# Accuracy Score                                           1
# Accuracy Type                                      rooftop
# County                                     Davidson County
# Zip                                                  37203
# matches
#
#                                        7   \
# Cluster Name                     CDM Jail
# Street                 5113 Harding Place
# City                            Nashville
# State                                  TN
# Facility Type       Correctional Facility
# Cluster Start Date                4/13/20
# # Cases                                22
# Latitude                          36.0896
# Longitude                        -86.6885
# Accuracy Score                          1
# Accuracy Type         range_interpolation
# County                    Davidson County
# Zip                                 37211
# matches
#
#                                                                   8   \
# Cluster Name        Nashville Community Care & Rehabilitation Center
# Street                                     1414 County Hospital Road
# City                                                       Nashville
# State                                                             TN
# Facility Type                                                   LTCF
# Cluster Start Date                                           4/15/20
# # Cases                                                           47
# Latitude                                                     36.1741
# Longitude                                                   -86.8456
# Accuracy Score                                                     1
# Accuracy Type                                                rooftop
# County                                               Davidson County
# Zip                                                            37218
# matches
#
#                                       9   \
# Cluster Name                     Cargill
# Street               2621 Eugenia Avenue
# City                           Nashville
# State                                 TN
# Facility Type       Commercial-Warehouse
# Cluster Start Date               4/21/20
# # Cases                               22
# Latitude                          36.116
# Longitude                       -86.7547
# Accuracy Score                         1
# Accuracy Type        range_interpolation
# County                   Davidson County
# Zip                                37211
# matches
#
#                                                       10  \
# Cluster Name        Bethany Center for Rehab and Healing
# Street                                   421 Ocala Drive
# City                                           Nashville
# State                                                 TN
# Facility Type                                       LTCF
# Cluster Start Date                               4/27/20
# # Cases                                              133
# Latitude                                         36.0513
# Longitude                                       -86.7146
# Accuracy Score                                         1
# Accuracy Type                        range_interpolation
# County                                   Davidson County
# Zip                                                37211
# matches
#
#                                             11  ...  \
# Cluster Name           Knowles Assisted Living  ...
# Street              1010 Camilla Caldwell Lane  ...
# City                                 Nashville  ...
# State                                       TN  ...
# Facility Type                             LTCF  ...
# Cluster Start Date                     4/27/20  ...
# # Cases                                     41  ...
# Latitude                               36.1741  ...
# Longitude                             -86.8456  ...
# Accuracy Score                               1  ...
# Accuracy Type                          rooftop  ...
# County                         Davidson County  ...
# Zip                                      37218  ...
# matches                                         ...
#
#                                                      48  \
# Cluster Name        Lois DeBerry Special Needs Facility
# Street                          7575 Cockrill Bend Blvd
# City                                          Nashville
# State                                                TN
# Facility Type                     Correctional Facility
# Cluster Start Date                               9/1/20
# # Cases                                              62
# Latitude                                        36.1848
# Longitude                                      -86.8992
# Accuracy Score                                        1
# Accuracy Type                                   rooftop
# County                                  Davidson County
# Zip                                               37209
# matches                         7575 Cockrill Bend Blvd
#
#                                                  49  \
# Cluster Name        Riverbend Max Security Prison-2
# Street                      7475 Cockrill Bend Blvd
# City                                      Nashville
# State                                            TN
# Facility Type                 Correctional Facility
# Cluster Start Date                           9/1/20
# # Cases                                          60
# Latitude                                    36.1848
# Longitude                                  -86.8992
# Accuracy Score                                    1
# Accuracy Type                               rooftop
# County                              Davidson County
# Zip                                           37209
# matches                     7475 Cockrill Bend Blvd
#
#                                                          50  \
# Cluster Name        Debra Johnson Rehab/TN Prison for Women
# Street                                     3881 Stewarts Ln
# City                                              Nashville
# State                                                    TN
# Facility Type                         Correctional Facility
# Cluster Start Date                                   9/1/20
# # Cases                                                 216
# Latitude                                            36.1994
# Longitude                                          -86.8669
# Accuracy Score                                            1
# Accuracy Type                                       rooftop
# County                                      Davidson County
# Zip                                                   37218
# matches                                    3881 Stewarts Ln
#
#                                                           52  \
# Cluster Name        Green Hills Center for Rehab and Healing
# Street                                    3939 Hillsboro Cir
# City                                               Nashville
# State                                                     TN
# Facility Type                                           LTCF
# Cluster Start Date                                    9/7/20
# # Cases                                                   45
# Latitude                                             36.1049
# Longitude                                           -86.8196
# Accuracy Score                                             1
# Accuracy Type                            range_interpolation
# County                                       Davidson County
# Zip                                                    37215
# matches                                   3939 Hillsboro Cir
#
#                                      53                        57  \
# Cluster Name           Tennessee Titans  One Stone Church Service
# Street              460 Great Circle Rd        1101 Stainback Ave
# City                          Nashville                 Nashville
# State                                TN                        TN
# Facility Type                     Other                    Church
# Cluster Start Date              9/12/20                   9/22/20
# # Cases                              23                        10
# Latitude                        36.1989                   36.1898
# Longitude                      -86.8044                  -86.7652
# Accuracy Score                        1                         1
# Accuracy Type                   rooftop       range_interpolation
# County                  Davidson County           Davidson County
# Zip                               37228                     37207
# matches             460 Great Circle Rd        1101 Stainback Ave
#
#                                      58  \
# Cluster Name               Miss Kelli's
# Street               207 Printers Alley
# City                          Nashville
# State                                TN
# Facility Type                       Bar
# Cluster Start Date              10/1/20
# # Cases                              14
# Latitude                        36.1639
# Longitude                      -86.7785
# Accuracy Score                        1
# Accuracy Type       range_interpolation
# County                  Davidson County
# Zip                               37201
# matches              207 Printers Alley
#
#                                                            59  \
# Cluster Name        Nashville Rescue Mission - Women's Campus
# Street                                 1716 Rosa L Parks Blvd
# City                                                Nashville
# State                                                      TN
# Facility Type                               Congregate Living
# Cluster Start Date                                    10/1/20
# # Cases                                                    70
# Latitude                                              36.1817
# Longitude                                            -86.7968
# Accuracy Score                                              1
# Accuracy Type                                         rooftop
# County                                        Davidson County
# Zip                                                     37208
# matches                                1716 ROSA L PARKS BLVD
#
#                                        60                  61
# Cluster Name        Link Systems Electric  Iron Tribe Belmont
# Street                     444 McNally Dr   3201 Belmont Blvd
# City                            Nashville           Nashville
# State                                  TN                  TN
# Facility Type                       Other                 Gym
# Cluster Start Date               10/16/20            10/20/20
# # Cases                                12                  14
# Latitude                          36.0926              36.117
# Longitude                        -86.7403            -86.7983
# Accuracy Score                        0.9                   1
# Accuracy Type         range_interpolation             rooftop
# County                    Davidson County     Davidson County
# Zip                                 37211               37212
# matches                    444 McNally Dr        Belmont Blvd
#
# [14 rows x 51 columns]

# %%
clusters_violations_fuzzy[clusters_violations_fuzzy['matches'] != ''].shape
# Out:
# (28, 14)

# %%
clusters.columns
# Out:
# Index(['Cluster Name', 'Street', 'City', 'State', 'Facility Type',
#        'Cluster Start Date', '# Cases', 'Latitude', 'Longitude',
#        'Accuracy Score', 'Accuracy Type', 'County', 'Zip'],
#       dtype='object')

# %%
hub_geocodio.columns
# Out:
# Index(['Request #', 'Status', 'Date / Time Opened', 'Date / Time Closed',
#        'Contact Type', 'State Issue', 'Closed When Created', 'Address', 'City',
#        'Council District', 'ZIP', 'Mapped Location', 'Address_geo', 'City_geo',
#        'ZIP_geo', 'state', 'Latitude', 'Longitude', 'Accuracy Score',
#        'Accuracy Type', 'Number', 'Street', 'City.1', 'State', 'County',
#        'Zip'],
#       dtype='object')

# %% [markdown]
# ## Merge Fuzzied Clusters to Hub Violations DF

# %%
fuzzy_merge_df = clusters_violations_fuzzy.merge(
    hub_geocodio, left_on='matches', right_on='Address', suffixes=['_clusters', '_violations'])

# %%
fuzzy_merge_df
# Out:
#                               Cluster Name        Street_clusters  \
# 0    Trevecca Center for Rehab and Healing  329 Murfreesboro Pike
# 1         Montgomery Bell Academy job site      4001 Harding Pike
# 2         Montgomery Bell Academy job site      4001 Harding Pike
# 3         Montgomery Bell Academy job site      4001 Harding Pike
# 4         Montgomery Bell Academy job site      4001 Harding Pike
# ..                                     ...                    ...
# 163                  Link Systems Electric         444 McNally Dr
# 164                  Link Systems Electric         444 McNally Dr
# 165                  Link Systems Electric         444 McNally Dr
# 166                     Iron Tribe Belmont      3201 Belmont Blvd
# 167                     Iron Tribe Belmont      3201 Belmont Blvd
#
#     City_clusters State_clusters Facility Type Cluster Start Date  # Cases  \
# 0       Nashville             TN          LTCF             4/4/20      102
# 1       Nashville             TN  Construction             5/8/20       75
# 2       Nashville             TN  Construction             5/8/20       75
# 3       Nashville             TN  Construction             5/8/20       75
# 4       Nashville             TN  Construction             5/8/20       75
# ..            ...            ...           ...                ...      ...
# 163     Nashville             TN         Other           10/16/20       12
# 164     Nashville             TN         Other           10/16/20       12
# 165     Nashville             TN         Other           10/16/20       12
# 166     Nashville             TN           Gym           10/20/20       14
# 167     Nashville             TN           Gym           10/20/20       14
#
#      Latitude_clusters  Longitude_clusters  Accuracy Score_clusters  ...  \
# 0            36.144764          -86.755659                      1.0  ...
# 1            36.093008          -86.845540                      0.7  ...
# 2            36.093008          -86.845540                      0.7  ...
# 3            36.093008          -86.845540                      0.7  ...
# 4            36.093008          -86.845540                      0.7  ...
# ..                 ...                 ...                      ...  ...
# 163          36.092556          -86.740288                      0.9  ...
# 164          36.092556          -86.740288                      0.9  ...
# 165          36.092556          -86.740288                      0.9  ...
# 166          36.116961          -86.798286                      1.0  ...
# 167          36.116961          -86.798286                      1.0  ...
#
#     Latitude_violations Longitude_violations  Accuracy Score_violations  \
# 0             36.144764           -86.755659                        1.0
# 1             36.093008           -86.845540                        0.7
# 2             36.093008           -86.845540                        0.7
# 3             36.093008           -86.845540                        0.7
# 4             36.093008           -86.845540                        0.7
# ..                  ...                  ...                        ...
# 163           36.092556           -86.740288                        0.9
# 164           36.092556           -86.740288                        0.9
# 165           36.092556           -86.740288                        0.9
# 166           36.119203           -86.795683                        1.0
# 167           36.119203           -86.795683                        1.0
#
#     Accuracy Type_violations  Number  Street_violations     City.1  \
# 0                    rooftop     329  Murfreesboro Pike  Nashville
# 1        range_interpolation    4001         Harding Pl  Nashville
# 2        range_interpolation    4001         Harding Pl  Nashville
# 3        range_interpolation    4001         Harding Pl  Nashville
# 4        range_interpolation    4001         Harding Pl  Nashville
# ..                       ...     ...                ...        ...
# 163      range_interpolation     444        Mc Nally Dr  Nashville
# 164      range_interpolation     444        Mc Nally Dr  Nashville
# 165      range_interpolation     444        Mc Nally Dr  Nashville
# 166            street_center     NaN       Belmont Blvd  Nashville
# 167            street_center     NaN       Belmont Blvd  Nashville
#
#     State_violations County_violations  Zip_violations
# 0                 TN   Davidson County           37210
# 1                 TN   Davidson County           37215
# 2                 TN   Davidson County           37215
# 3                 TN   Davidson County           37215
# 4                 TN   Davidson County           37215
# ..               ...               ...             ...
# 163               TN   Davidson County           37211
# 164               TN   Davidson County           37211
# 165               TN   Davidson County           37211
# 166               TN   Davidson County           37212
# 167               TN   Davidson County           37212
#
# [168 rows x 40 columns]

# %%
fuzzy_merge_df.T
# Out:
#                                                              0    \
# Cluster Name               Trevecca Center for Rehab and Healing
# Street_clusters                            329 Murfreesboro Pike
# City_clusters                                          Nashville
# State_clusters                                                TN
# Facility Type                                               LTCF
# Cluster Start Date                                        4/4/20
# # Cases                                                      102
# Latitude_clusters                                        36.1448
# Longitude_clusters                                      -86.7557
# Accuracy Score_clusters                                        1
# Accuracy Type_clusters                                   rooftop
# County_clusters                                  Davidson County
# Zip_clusters                                               37210
# matches                                    329 Murfreesboro Pike
# Request #                                                 429008
# Status                                                    Closed
# Date / Time Opened                           2020-07-28 14:16:20
# Date / Time Closed                           2020-07-29 18:46:11
# Contact Type                                                 NaN
# State Issue                                                False
# Closed When Created                                        False
# Address                                    329 Murfreesboro Pike
# City_violations                                        NASHVILLE
# Council District                                              17
# ZIP                                                        37210
# Mapped Location                            (36.14456, -86.75456)
# Address_geo                                329 Murfreesboro Pike
# City_geo                                               NASHVILLE
# ZIP_geo                                                    37210
# state                                                         TN
# Latitude_violations                                      36.1448
# Longitude_violations                                    -86.7557
# Accuracy Score_violations                                      1
# Accuracy Type_violations                                 rooftop
# Number                                                       329
# Street_violations                              Murfreesboro Pike
# City.1                                                 Nashville
# State_violations                                              TN
# County_violations                                Davidson County
# Zip_violations                                             37210
#
#                                                         1    \
# Cluster Name               Montgomery Bell Academy job site
# Street_clusters                           4001 Harding Pike
# City_clusters                                     Nashville
# State_clusters                                           TN
# Facility Type                                  Construction
# Cluster Start Date                                   5/8/20
# # Cases                                                  75
# Latitude_clusters                                    36.093
# Longitude_clusters                                 -86.8455
# Accuracy Score_clusters                                 0.7
# Accuracy Type_clusters                  range_interpolation
# County_clusters                             Davidson County
# Zip_clusters                                          37215
# matches                                   4001 Harding Pike
# Request #                                            339597
# Status                                               Closed
# Date / Time Opened                      2020-04-05 17:13:59
# Date / Time Closed                      2020-04-10 17:19:55
# Contact Type                                            NaN
# State Issue                                           False
# Closed When Created                                   False
# Address                                   4001 Harding Pike
# City_violations                                   NASHVILLE
# Council District                                         24
# ZIP                                                   37205
# Mapped Location            (36.12837600000001, -86.8345785)
# Address_geo                               4001 Harding Pike
# City_geo                                          NASHVILLE
# ZIP_geo                                               37205
# state                                                    TN
# Latitude_violations                                  36.093
# Longitude_violations                               -86.8455
# Accuracy Score_violations                               0.7
# Accuracy Type_violations                range_interpolation
# Number                                                 4001
# Street_violations                                Harding Pl
# City.1                                            Nashville
# State_violations                                         TN
# County_violations                           Davidson County
# Zip_violations                                        37215
#
#                                                         2    \
# Cluster Name               Montgomery Bell Academy job site
# Street_clusters                           4001 Harding Pike
# City_clusters                                     Nashville
# State_clusters                                           TN
# Facility Type                                  Construction
# Cluster Start Date                                   5/8/20
# # Cases                                                  75
# Latitude_clusters                                    36.093
# Longitude_clusters                                 -86.8455
# Accuracy Score_clusters                                 0.7
# Accuracy Type_clusters                  range_interpolation
# County_clusters                             Davidson County
# Zip_clusters                                          37215
# matches                                   4001 Harding Pike
# Request #                                            338380
# Status                                               Closed
# Date / Time Opened                      2020-04-03 14:32:43
# Date / Time Closed                      2020-04-10 17:23:47
# Contact Type                                            NaN
# State Issue                                           False
# Closed When Created                                   False
# Address                                   4001 Harding Pike
# City_violations                                   NASHVILLE
# Council District                                         24
# ZIP                                                   37205
# Mapped Location                       (36.12842, -86.83669)
# Address_geo                               4001 Harding Pike
# City_geo                                          NASHVILLE
# ZIP_geo                                               37205
# state                                                    TN
# Latitude_violations                                  36.093
# Longitude_violations                               -86.8455
# Accuracy Score_violations                               0.7
# Accuracy Type_violations                range_interpolation
# Number                                                 4001
# Street_violations                                Harding Pl
# City.1                                            Nashville
# State_violations                                         TN
# County_violations                           Davidson County
# Zip_violations                                        37215
#
#                                                         3    \
# Cluster Name               Montgomery Bell Academy job site
# Street_clusters                           4001 Harding Pike
# City_clusters                                     Nashville
# State_clusters                                           TN
# Facility Type                                  Construction
# Cluster Start Date                                   5/8/20
# # Cases                                                  75
# Latitude_clusters                                    36.093
# Longitude_clusters                                 -86.8455
# Accuracy Score_clusters                                 0.7
# Accuracy Type_clusters                  range_interpolation
# County_clusters                             Davidson County
# Zip_clusters                                          37215
# matches                                   4001 Harding Pike
# Request #                                            338362
# Status                                               Closed
# Date / Time Opened                      2020-04-03 14:23:57
# Date / Time Closed                      2020-04-10 17:19:39
# Contact Type                                            NaN
# State Issue                                           False
# Closed When Created                                   False
# Address                                   4001 Harding Pike
# City_violations                                   NASHVILLE
# Council District                                         24
# ZIP                                                   37205
# Mapped Location            (36.12837600000001, -86.8345785)
# Address_geo                               4001 Harding Pike
# City_geo                                          NASHVILLE
# ZIP_geo                                               37205
# state                                                    TN
# Latitude_violations                                  36.093
# Longitude_violations                               -86.8455
# Accuracy Score_violations                               0.7
# Accuracy Type_violations                range_interpolation
# Number                                                 4001
# Street_violations                                Harding Pl
# City.1                                            Nashville
# State_violations                                         TN
# County_violations                           Davidson County
# Zip_violations                                        37215
#
#                                                         4    \
# Cluster Name               Montgomery Bell Academy job site
# Street_clusters                           4001 Harding Pike
# City_clusters                                     Nashville
# State_clusters                                           TN
# Facility Type                                  Construction
# Cluster Start Date                                   5/8/20
# # Cases                                                  75
# Latitude_clusters                                    36.093
# Longitude_clusters                                 -86.8455
# Accuracy Score_clusters                                 0.7
# Accuracy Type_clusters                  range_interpolation
# County_clusters                             Davidson County
# Zip_clusters                                          37215
# matches                                   4001 Harding Pike
# Request #                                            360377
# Status                                               Closed
# Date / Time Opened                      2020-05-06 14:42:30
# Date / Time Closed                      2020-05-07 15:09:19
# Contact Type                                            NaN
# State Issue                                           False
# Closed When Created                                   False
# Address                                   4001 Harding Pike
# City_violations                                   NASHVILLE
# Council District                                         24
# ZIP                                                   37205
# Mapped Location                   (36.1284249, -86.8366934)
# Address_geo                               4001 Harding Pike
# City_geo                                          NASHVILLE
# ZIP_geo                                               37205
# state                                                    TN
# Latitude_violations                                  36.093
# Longitude_violations                               -86.8455
# Accuracy Score_violations                               0.7
# Accuracy Type_violations                range_interpolation
# Number                                                 4001
# Street_violations                                Harding Pl
# City.1                                            Nashville
# State_violations                                         TN
# County_violations                           Davidson County
# Zip_violations                                        37215
#
#                                                         5    \
# Cluster Name               Montgomery Bell Academy job site
# Street_clusters                           4001 Harding Pike
# City_clusters                                     Nashville
# State_clusters                                           TN
# Facility Type                                  Construction
# Cluster Start Date                                   5/8/20
# # Cases                                                  75
# Latitude_clusters                                    36.093
# Longitude_clusters                                 -86.8455
# Accuracy Score_clusters                                 0.7
# Accuracy Type_clusters                  range_interpolation
# County_clusters                             Davidson County
# Zip_clusters                                          37215
# matches                                   4001 Harding Pike
# Request #                                            365255
# Status                                               Closed
# Date / Time Opened                      2020-05-12 17:04:53
# Date / Time Closed                      2020-05-13 16:37:42
# Contact Type                                            NaN
# State Issue                                           False
# Closed When Created                                   False
# Address                                   4001 Harding Pike
# City_violations                                   NASHVILLE
# Council District                                         24
# ZIP                                                   37205
# Mapped Location                   (36.1277086, -86.8366003)
# Address_geo                               4001 Harding Pike
# City_geo                                          NASHVILLE
# ZIP_geo                                               37205
# state                                                    TN
# Latitude_violations                                  36.093
# Longitude_violations                               -86.8455
# Accuracy Score_violations                               0.7
# Accuracy Type_violations                range_interpolation
# Number                                                 4001
# Street_violations                                Harding Pl
# City.1                                            Nashville
# State_violations                                         TN
# County_violations                           Davidson County
# Zip_violations                                        37215
#
#                                                         6    \
# Cluster Name               Montgomery Bell Academy job site
# Street_clusters                           4001 Harding Pike
# City_clusters                                     Nashville
# State_clusters                                           TN
# Facility Type                                  Construction
# Cluster Start Date                                   5/8/20
# # Cases                                                  75
# Latitude_clusters                                    36.093
# Longitude_clusters                                 -86.8455
# Accuracy Score_clusters                                 0.7
# Accuracy Type_clusters                  range_interpolation
# County_clusters                             Davidson County
# Zip_clusters                                          37215
# matches                                   4001 Harding Pike
# Request #                                            401263
# Status                                               Closed
# Date / Time Opened                      2020-06-26 13:52:13
# Date / Time Closed                      2020-06-29 18:36:50
# Contact Type                                            NaN
# State Issue                                           False
# Closed When Created                                   False
# Address                                   4001 Harding Pike
# City_violations                                   NASHVILLE
# Council District                                         24
# ZIP                                                   37205
# Mapped Location                       (36.12853, -86.83647)
# Address_geo                               4001 Harding Pike
# City_geo                                          NASHVILLE
# ZIP_geo                                               37205
# state                                                    TN
# Latitude_violations                                  36.093
# Longitude_violations                               -86.8455
# Accuracy Score_violations                               0.7
# Accuracy Type_violations                range_interpolation
# Number                                                 4001
# Street_violations                                Harding Pl
# City.1                                            Nashville
# State_violations                                         TN
# County_violations                           Davidson County
# Zip_violations                                        37215
#
#                                                                 7    \
# Cluster Name                       Montgomery Bell Academy job site
# Street_clusters                                   4001 Harding Pike
# City_clusters                                             Nashville
# State_clusters                                                   TN
# Facility Type                                          Construction
# Cluster Start Date                                           5/8/20
# # Cases                                                          75
# Latitude_clusters                                            36.093
# Longitude_clusters                                         -86.8455
# Accuracy Score_clusters                                         0.7
# Accuracy Type_clusters                          range_interpolation
# County_clusters                                     Davidson County
# Zip_clusters                                                  37215
# matches                                           4001 Harding Pike
# Request #                                                    435775
# Status                                                       Closed
# Date / Time Opened                              2020-08-03 05:23:34
# Date / Time Closed                              2020-08-03 17:52:24
# Contact Type                                                    NaN
# State Issue                                                   False
# Closed When Created                                           False
# Address                                           4001 Harding Pike
# City_violations                                           NASHVILLE
# Council District                                                 24
# ZIP                                                           37205
# Mapped Location            (36.127867291643206, -86.83734249458159)
# Address_geo                                       4001 Harding Pike
# City_geo                                                  NASHVILLE
# ZIP_geo                                                       37205
# state                                                            TN
# Latitude_violations                                          36.093
# Longitude_violations                                       -86.8455
# Accuracy Score_violations                                       0.7
# Accuracy Type_violations                        range_interpolation
# Number                                                         4001
# Street_violations                                        Harding Pl
# City.1                                                    Nashville
# State_violations                                                 TN
# County_violations                                   Davidson County
# Zip_violations                                                37215
#
#                                                          8    \
# Cluster Name                Montgomery Bell Academy job site
# Street_clusters                            4001 Harding Pike
# City_clusters                                      Nashville
# State_clusters                                            TN
# Facility Type                                   Construction
# Cluster Start Date                                    5/8/20
# # Cases                                                   75
# Latitude_clusters                                     36.093
# Longitude_clusters                                  -86.8455
# Accuracy Score_clusters                                  0.7
# Accuracy Type_clusters                   range_interpolation
# County_clusters                              Davidson County
# Zip_clusters                                           37215
# matches                                    4001 Harding Pike
# Request #                                             475228
# Status                                                Closed
# Date / Time Opened                       2020-10-04 14:57:01
# Date / Time Closed                       2020-10-05 13:53:06
# Contact Type                                             NaN
# State Issue                                            False
# Closed When Created                                    False
# Address                                    4001 Harding Pike
# City_violations                                    NASHVILLE
# Council District                                          24
# ZIP                                                    37205
# Mapped Location            (36.12879426159236, -86.83709815)
# Address_geo                                4001 Harding Pike
# City_geo                                           NASHVILLE
# ZIP_geo                                                37205
# state                                                     TN
# Latitude_violations                                   36.093
# Longitude_violations                                -86.8455
# Accuracy Score_violations                                0.7
# Accuracy Type_violations                 range_interpolation
# Number                                                  4001
# Street_violations                                 Harding Pl
# City.1                                             Nashville
# State_violations                                          TN
# County_violations                            Davidson County
# Zip_violations                                         37215
#
#                                                                      9    ...  \
# Cluster Name               Grand Hyatt Hotel (Power Design Inc) job site  ...
# Street_clusters                                            1000 Broadway  ...
# City_clusters                                                  Nashville  ...
# State_clusters                                                        TN  ...
# Facility Type                                               Construction  ...
# Cluster Start Date                                               5/19/20  ...
# # Cases                                                               23  ...
# Latitude_clusters                                                36.1578  ...
# Longitude_clusters                                              -86.7842  ...
# Accuracy Score_clusters                                                1  ...
# Accuracy Type_clusters                               range_interpolation  ...
# County_clusters                                          Davidson County  ...
# Zip_clusters                                                       37203  ...
# matches                                                    1000 Broadway  ...
# Request #                                                         341201  ...
# Status                                                            Closed  ...
# Date / Time Opened                                   2020-04-07 15:45:42  ...
# Date / Time Closed                                   2020-04-10 17:10:37  ...
# Contact Type                                                         NaN  ...
# State Issue                                                        False  ...
# Closed When Created                                                False  ...
# Address                                                    1000 Broadway  ...
# City_violations                                                NASHVILLE  ...
# Council District                                                      19  ...
# ZIP                                                                37203  ...
# Mapped Location                                (36.1579945, -86.7842417)  ...
# Address_geo                                                1000 Broadway  ...
# City_geo                                                       NASHVILLE  ...
# ZIP_geo                                                            37203  ...
# state                                                                 TN  ...
# Latitude_violations                                              36.1578  ...
# Longitude_violations                                            -86.7842  ...
# Accuracy Score_violations                                              1  ...
# Accuracy Type_violations                             range_interpolation  ...
# Number                                                              1000  ...
# Street_violations                                               Broadway  ...
# City.1                                                         Nashville  ...
# State_violations                                                      TN  ...
# County_violations                                        Davidson County  ...
# Zip_violations                                                     37203  ...
#
#                                                158                      159  \
# Cluster Name                          Miss Kelli's             Miss Kelli's
# Street_clusters                 207 Printers Alley       207 Printers Alley
# City_clusters                            Nashville                Nashville
# State_clusters                                  TN                       TN
# Facility Type                                  Bar                      Bar
# Cluster Start Date                         10/1/20                  10/1/20
# # Cases                                         14                       14
# Latitude_clusters                          36.1639                  36.1639
# Longitude_clusters                        -86.7785                 -86.7785
# Accuracy Score_clusters                          1                        1
# Accuracy Type_clusters         range_interpolation      range_interpolation
# County_clusters                    Davidson County          Davidson County
# Zip_clusters                                 37201                    37201
# matches                         207 Printers Alley       207 Printers Alley
# Request #                                   471299                   482950
# Status                                      Closed                   Closed
# Date / Time Opened             2020-09-26 18:30:59      2020-10-18 04:24:54
# Date / Time Closed             2020-09-28 16:30:16      2020-10-19 16:03:15
# Contact Type                                   NaN                      NaN
# State Issue                                  False                    False
# Closed When Created                          False                    False
# Address                         207 Printers Alley       207 Printers Alley
# City_violations                          NASHVILLE                NASHVILLE
# Council District                                19                       19
# ZIP                                          37201                    37201
# Mapped Location            (36.164369, -86.778515)  (36.164369, -86.778515)
# Address_geo                     207 Printers Alley       207 Printers Alley
# City_geo                                 NASHVILLE                NASHVILLE
# ZIP_geo                                      37201                    37201
# state                                           TN                       TN
# Latitude_violations                        36.1639                  36.1639
# Longitude_violations                      -86.7785                 -86.7785
# Accuracy Score_violations                        1                        1
# Accuracy Type_violations       range_interpolation      range_interpolation
# Number                                         207                      207
# Street_violations                     Printers Aly             Printers Aly
# City.1                                   Nashville                Nashville
# State_violations                                TN                       TN
# County_violations                  Davidson County          Davidson County
# Zip_violations                               37201                    37201
#
#                                                160  \
# Cluster Name                          Miss Kelli's
# Street_clusters                 207 Printers Alley
# City_clusters                            Nashville
# State_clusters                                  TN
# Facility Type                                  Bar
# Cluster Start Date                         10/1/20
# # Cases                                         14
# Latitude_clusters                          36.1639
# Longitude_clusters                        -86.7785
# Accuracy Score_clusters                          1
# Accuracy Type_clusters         range_interpolation
# County_clusters                    Davidson County
# Zip_clusters                                 37201
# matches                         207 Printers Alley
# Request #                                   487902
# Status                                      Closed
# Date / Time Opened             2020-10-25 04:22:34
# Date / Time Closed             2020-10-26 14:37:35
# Contact Type                                   NaN
# State Issue                                  False
# Closed When Created                          False
# Address                         207 Printers Alley
# City_violations                          NASHVILLE
# Council District                                19
# ZIP                                          37201
# Mapped Location            (36.164369, -86.778515)
# Address_geo                     207 Printers Alley
# City_geo                                 NASHVILLE
# ZIP_geo                                      37201
# state                                           TN
# Latitude_violations                        36.1639
# Longitude_violations                      -86.7785
# Accuracy Score_violations                        1
# Accuracy Type_violations       range_interpolation
# Number                                         207
# Street_violations                     Printers Aly
# City.1                                   Nashville
# State_violations                                TN
# County_violations                  Davidson County
# Zip_violations                               37201
#
#                                                                  161  \
# Cluster Name               Nashville Rescue Mission - Women's Campus
# Street_clusters                               1716 Rosa L Parks Blvd
# City_clusters                                              Nashville
# State_clusters                                                    TN
# Facility Type                                      Congregate Living
# Cluster Start Date                                           10/1/20
# # Cases                                                           70
# Latitude_clusters                                            36.1817
# Longitude_clusters                                          -86.7968
# Accuracy Score_clusters                                            1
# Accuracy Type_clusters                                       rooftop
# County_clusters                                      Davidson County
# Zip_clusters                                                   37208
# matches                                       1716 ROSA L PARKS BLVD
# Request #                                                     336739
# Status                                                        Closed
# Date / Time Opened                               2020-04-01 17:39:36
# Date / Time Closed                               2020-04-10 16:59:56
# Contact Type                                                     NaN
# State Issue                                                    False
# Closed When Created                                            False
# Address                                       1716 ROSA L PARKS BLVD
# City_violations                                            NASHVILLE
# Council District                                                  19
# ZIP                                                            37208
# Mapped Location               (36.18169884457409, -86.7967557335612)
# Address_geo                                   1716 ROSA L PARKS BLVD
# City_geo                                                   NASHVILLE
# ZIP_geo                                                        37208
# state                                                             TN
# Latitude_violations                                          36.1817
# Longitude_violations                                        -86.7968
# Accuracy Score_violations                                          1
# Accuracy Type_violations                                     rooftop
# Number                                                          1716
# Street_violations                                  Rosa L Parks Blvd
# City.1                                                     Nashville
# State_violations                                                  TN
# County_violations                                    Davidson County
# Zip_violations                                                 37208
#
#                                                                162  \
# Cluster Name                                 Link Systems Electric
# Street_clusters                                     444 McNally Dr
# City_clusters                                            Nashville
# State_clusters                                                  TN
# Facility Type                                                Other
# Cluster Start Date                                        10/16/20
# # Cases                                                         12
# Latitude_clusters                                          36.0926
# Longitude_clusters                                        -86.7403
# Accuracy Score_clusters                                        0.9
# Accuracy Type_clusters                         range_interpolation
# County_clusters                                    Davidson County
# Zip_clusters                                                 37211
# matches                                             444 McNally Dr
# Request #                                                   479073
# Status                                                      Closed
# Date / Time Opened                             2020-10-11 00:52:25
# Date / Time Closed                             2020-10-12 14:12:04
# Contact Type                                                   NaN
# State Issue                                                  False
# Closed When Created                                          False
# Address                                             444 McNally Dr
# City_violations                                          NASHVILLE
# Council District                                                26
# ZIP                                                          37211
# Mapped Location            (36.09275076157706, -86.74174550000001)
# Address_geo                                         444 McNally Dr
# City_geo                                                 NASHVILLE
# ZIP_geo                                                      37211
# state                                                           TN
# Latitude_violations                                        36.0926
# Longitude_violations                                      -86.7403
# Accuracy Score_violations                                      0.9
# Accuracy Type_violations                       range_interpolation
# Number                                                         444
# Street_violations                                      Mc Nally Dr
# City.1                                                   Nashville
# State_violations                                                TN
# County_violations                                  Davidson County
# Zip_violations                                               37211
#
#                                                 163                       164  \
# Cluster Name                  Link Systems Electric     Link Systems Electric
# Street_clusters                      444 McNally Dr            444 McNally Dr
# City_clusters                             Nashville                 Nashville
# State_clusters                                   TN                        TN
# Facility Type                                 Other                     Other
# Cluster Start Date                         10/16/20                  10/16/20
# # Cases                                          12                        12
# Latitude_clusters                           36.0926                   36.0926
# Longitude_clusters                         -86.7403                  -86.7403
# Accuracy Score_clusters                         0.9                       0.9
# Accuracy Type_clusters          range_interpolation       range_interpolation
# County_clusters                     Davidson County           Davidson County
# Zip_clusters                                  37211                     37211
# matches                              444 McNally Dr            444 McNally Dr
# Request #                                    483497                    478085
# Status                                       Closed                    Closed
# Date / Time Opened              2020-10-19 15:58:47       2020-10-08 19:38:26
# Date / Time Closed              2020-10-20 13:57:26       2020-10-09 13:29:02
# Contact Type                                    NaN                       NaN
# State Issue                                   False                     False
# Closed When Created                           False                     False
# Address                              444 McNally Dr            444 McNally Dr
# City_violations                           NASHVILLE                 NASHVILLE
# Council District                                 26                        26
# ZIP                                           37211                     37211
# Mapped Location            (36.0930056, -86.741716)  (36.0930056, -86.741716)
# Address_geo                          444 McNally Dr            444 McNally Dr
# City_geo                                  NASHVILLE                 NASHVILLE
# ZIP_geo                                       37211                     37211
# state                                            TN                        TN
# Latitude_violations                         36.0926                   36.0926
# Longitude_violations                       -86.7403                  -86.7403
# Accuracy Score_violations                       0.9                       0.9
# Accuracy Type_violations        range_interpolation       range_interpolation
# Number                                          444                       444
# Street_violations                       Mc Nally Dr               Mc Nally Dr
# City.1                                    Nashville                 Nashville
# State_violations                                 TN                        TN
# County_violations                   Davidson County           Davidson County
# Zip_violations                                37211                     37211
#
#                                                 165  \
# Cluster Name                  Link Systems Electric
# Street_clusters                      444 McNally Dr
# City_clusters                             Nashville
# State_clusters                                   TN
# Facility Type                                 Other
# Cluster Start Date                         10/16/20
# # Cases                                          12
# Latitude_clusters                           36.0926
# Longitude_clusters                         -86.7403
# Accuracy Score_clusters                         0.9
# Accuracy Type_clusters          range_interpolation
# County_clusters                     Davidson County
# Zip_clusters                                  37211
# matches                              444 McNally Dr
# Request #                                    481365
# Status                                       Closed
# Date / Time Opened              2020-10-15 13:47:48
# Date / Time Closed              2020-10-16 13:27:18
# Contact Type                                    NaN
# State Issue                                   False
# Closed When Created                           False
# Address                              444 McNally Dr
# City_violations                           NASHVILLE
# Council District                                 26
# ZIP                                           37211
# Mapped Location            (36.0930056, -86.741716)
# Address_geo                          444 McNally Dr
# City_geo                                  NASHVILLE
# ZIP_geo                                       37211
# state                                            TN
# Latitude_violations                         36.0926
# Longitude_violations                       -86.7403
# Accuracy Score_violations                       0.9
# Accuracy Type_violations        range_interpolation
# Number                                          444
# Street_violations                       Mc Nally Dr
# City.1                                    Nashville
# State_violations                                 TN
# County_violations                   Davidson County
# Zip_violations                                37211
#
#                                                        166  \
# Cluster Name                            Iron Tribe Belmont
# Street_clusters                          3201 Belmont Blvd
# City_clusters                                    Nashville
# State_clusters                                          TN
# Facility Type                                          Gym
# Cluster Start Date                                10/20/20
# # Cases                                                 14
# Latitude_clusters                                   36.117
# Longitude_clusters                                -86.7983
# Accuracy Score_clusters                                  1
# Accuracy Type_clusters                             rooftop
# County_clusters                            Davidson County
# Zip_clusters                                         37212
# matches                                       Belmont Blvd
# Request #                                           339139
# Status                                              Closed
# Date / Time Opened                     2020-04-03 21:25:00
# Date / Time Closed                     2020-04-07 19:28:06
# Contact Type                                           NaN
# State Issue                                          False
# Closed When Created                                  False
# Address                                       Belmont Blvd
# City_violations                                  NASHVILLE
# Council District                                        18
# ZIP                                                  37212
# Mapped Location            (36.11748019999999, -86.797266)
# Address_geo                                   Belmont Blvd
# City_geo                                         NASHVILLE
# ZIP_geo                                              37212
# state                                                   TN
# Latitude_violations                                36.1192
# Longitude_violations                              -86.7957
# Accuracy Score_violations                                1
# Accuracy Type_violations                     street_center
# Number                                                 NaN
# Street_violations                             Belmont Blvd
# City.1                                           Nashville
# State_violations                                        TN
# County_violations                          Davidson County
# Zip_violations                                       37212
#
#                                                         167
# Cluster Name                             Iron Tribe Belmont
# Street_clusters                           3201 Belmont Blvd
# City_clusters                                     Nashville
# State_clusters                                           TN
# Facility Type                                           Gym
# Cluster Start Date                                 10/20/20
# # Cases                                                  14
# Latitude_clusters                                    36.117
# Longitude_clusters                                 -86.7983
# Accuracy Score_clusters                                   1
# Accuracy Type_clusters                              rooftop
# County_clusters                             Davidson County
# Zip_clusters                                          37212
# matches                                        Belmont Blvd
# Request #                                            360058
# Status                                               Closed
# Date / Time Opened                      2020-05-05 23:48:25
# Date / Time Closed                      2020-05-07 15:12:02
# Contact Type                                            NaN
# State Issue                                           False
# Closed When Created                                   False
# Address                                        Belmont Blvd
# City_violations                                   NASHVILLE
# Council District                                         18
# ZIP                                                   37212
# Mapped Location            (36.12305029999999, -86.7943525)
# Address_geo                                    Belmont Blvd
# City_geo                                          NASHVILLE
# ZIP_geo                                               37212
# state                                                    TN
# Latitude_violations                                 36.1192
# Longitude_violations                               -86.7957
# Accuracy Score_violations                                 1
# Accuracy Type_violations                      street_center
# Number                                                  NaN
# Street_violations                              Belmont Blvd
# City.1                                            Nashville
# State_violations                                         TN
# County_violations                           Davidson County
# Zip_violations                                        37212
#
# [40 rows x 168 columns]

# %%
fuzzy_merge_df.to_csv('fuzzy_merge_df.csv')

# %%
fuzzy_merge_df['Cluster Name'].value_counts()
# Out:
# Kid Rock's Big Ass Honky Tonk                    47
# Tootsie's                                        27
# Winner's                                         27
# Dawghouse Saloon                                  9
# Montgomery Bell Academy job site                  8
# Hermitage Hall                                    6
# Miss Kelli's                                      6
# Good Samaritan Health & Healing                   6
# Life Care Center Old Hickory Village              5
# Link Systems Electric                             4
# Debra Johnson Rehab/TN Prison for Women           3
# Grand Hyatt Hotel (Power Design Inc) job site     2
# One Stone Church Service                          2
# Iron Tribe Belmont                                2
# Standing Tall Music City                          1
# Nashville Center for Rehab and Healing (2)        1
# Trevecca Center for Rehab and Healing             1
# Tennessee Titans                                  1
# Lakeshore Meadows                                 1
# Metro Water Services                              1
# Lois DeBerry Special Needs Facility               1
# Nashville Rescue Mission - Women's Campus         1
# Ahava / Grace Healthcare of White's Creek         1
# Green Hills Center for Rehab and Healing          1
# Riverbend Max Security Prison-2                   1
# Loser's                                           1
# Dogwood                                           1
# Belmont Village of Green Hills                    1
# Name: Cluster Name, dtype: int64

# %% [markdown]
# ## Create Buffer Zones around each Cluster Point
# ### Create a GeoDataFrame with the Clusters DataFrame

# %%
clusters_locations = clusters[clusters['Latitude'].notna()]

# %%
clusters_locations['Buffer_Geometry'] = clusters_locations.apply(lambda x: Point((float(x.Longitude),
                                              float(x.Latitude))),
                             axis=1)

# %%
clusters_locations.head()
# Out:
#                             Cluster Name                 Street       City  \
# 0                     Vanderbilt Parties                    NaN        NaN
# 1               Event at Clementine Hall  4710 Charlotte Avenue  Nashville
# 2                      Religious Retreat                    NaN        NaN
# 3    The Health Center at Richland Place   504 Elmington Avenue  Nashville
# 4  Trevecca Center for Rehab and Healing  329 Murfreesboro Pike  Nashville
#
#   State     Facility Type Cluster Start Date  # Cases   Latitude  Longitude  \
# 0    TN  Social Gathering            3/11/20       49  35.858564 -86.349357
# 1    TN  Social Gathering            3/14/20       23  36.152300 -86.843597
# 2    TN  Social Gathering            3/25/20       18  35.858564 -86.349357
# 3    TN              LTCF             4/3/20       47  36.128791 -86.818522
# 4    TN              LTCF             4/4/20      102  36.144764 -86.755659
#
#    Accuracy Score        Accuracy Type           County      Zip  \
# 0             1.0                state              NaN      NaN
# 1             1.0  range_interpolation  Davidson County  37209.0
# 2             1.0                state              NaN      NaN
# 3             1.0  range_interpolation  Davidson County  37205.0
# 4             1.0              rooftop  Davidson County  37210.0
#
#                         Buffer_Geometry
# 0          POINT (-86.349357 35.858564)
# 1            POINT (-86.843597 36.1523)
# 2          POINT (-86.349357 35.858564)
# 3          POINT (-86.818522 36.128791)
# 4  POINT (-86.75565899999999 36.144764)

# %%
geometry = clusters_locations['Buffer_Geometry']
clusters_locations_geodf = gpd.GeoDataFrame(clusters_locations, crs="EPSG:4326", geometry=geometry)

# %%
clusters_locations_geodf = clusters_locations_geodf.drop('Buffer_Geometry', axis=1)
clusters_locations_geodf['Buffer_Geometry'] = clusters_locations_geodf['geometry']
clusters_locations_geodf = clusters_locations_geodf.drop('geometry', axis=1)

# %%
clusters_locations_geodf.head()
# Out:
#                             Cluster Name                 Street       City  \
# 0                     Vanderbilt Parties                    NaN        NaN
# 1               Event at Clementine Hall  4710 Charlotte Avenue  Nashville
# 2                      Religious Retreat                    NaN        NaN
# 3    The Health Center at Richland Place   504 Elmington Avenue  Nashville
# 4  Trevecca Center for Rehab and Healing  329 Murfreesboro Pike  Nashville
#
#   State     Facility Type Cluster Start Date  # Cases   Latitude  Longitude  \
# 0    TN  Social Gathering            3/11/20       49  35.858564 -86.349357
# 1    TN  Social Gathering            3/14/20       23  36.152300 -86.843597
# 2    TN  Social Gathering            3/25/20       18  35.858564 -86.349357
# 3    TN              LTCF             4/3/20       47  36.128791 -86.818522
# 4    TN              LTCF             4/4/20      102  36.144764 -86.755659
#
#    Accuracy Score        Accuracy Type           County      Zip  \
# 0             1.0                state              NaN      NaN
# 1             1.0  range_interpolation  Davidson County  37209.0
# 2             1.0                state              NaN      NaN
# 3             1.0  range_interpolation  Davidson County  37205.0
# 4             1.0              rooftop  Davidson County  37210.0
#
#               Buffer_Geometry
# 0  POINT (-86.34936 35.85856)
# 1  POINT (-86.84360 36.15230)
# 2  POINT (-86.34936 35.85856)
# 3  POINT (-86.81852 36.12879)
# 4  POINT (-86.75566 36.14476)

# %%
clusters_locations_geodf['Buffer_Zone'] = clusters_locations_geodf['Buffer_Geometry'].buffer(.0001, resolution=20)
# Out:
# <ipython-input-43-ff63d55ec73f>:1: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   clusters_locations_geodf['Buffer_Zone'] = clusters_locations_geodf['Buffer_Geometry'].buffer(.0001, resolution=20)

# %%
clusters_locations_geodf
# Out:
#                                  Cluster Name                  Street  \
# 0                          Vanderbilt Parties                     NaN
# 1                    Event at Clementine Hall   4710 Charlotte Avenue
# 2                           Religious Retreat                     NaN
# 3         The Health Center at Richland Place    504 Elmington Avenue
# 4       Trevecca Center for Rehab and Healing   329 Murfreesboro Pike
# ..                                        ...                     ...
# 57                   One Stone Church Service      1101 Stainback Ave
# 58                               Miss Kelli's      207 Printers Alley
# 59  Nashville Rescue Mission - Women's Campus  1716 Rosa L Parks Blvd
# 60                      Link Systems Electric          444 McNally Dr
# 61                         Iron Tribe Belmont       3201 Belmont Blvd
#
#          City State      Facility Type Cluster Start Date  # Cases   Latitude  \
# 0         NaN    TN   Social Gathering            3/11/20       49  35.858564
# 1   Nashville    TN   Social Gathering            3/14/20       23  36.152300
# 2         NaN    TN   Social Gathering            3/25/20       18  35.858564
# 3   Nashville    TN               LTCF             4/3/20       47  36.128791
# 4   Nashville    TN               LTCF             4/4/20      102  36.144764
# ..        ...   ...                ...                ...      ...        ...
# 57  Nashville    TN             Church            9/22/20       10  36.189795
# 58  Nashville    TN                Bar            10/1/20       14  36.163931
# 59  Nashville    TN  Congregate Living            10/1/20       70  36.181699
# 60  Nashville    TN              Other           10/16/20       12  36.092556
# 61  Nashville    TN                Gym           10/20/20       14  36.116961
#
#     Longitude  Accuracy Score        Accuracy Type           County      Zip  \
# 0  -86.349357             1.0                state              NaN      NaN
# 1  -86.843597             1.0  range_interpolation  Davidson County  37209.0
# 2  -86.349357             1.0                state              NaN      NaN
# 3  -86.818522             1.0  range_interpolation  Davidson County  37205.0
# 4  -86.755659             1.0              rooftop  Davidson County  37210.0
# ..        ...             ...                  ...              ...      ...
# 57 -86.765180             1.0  range_interpolation  Davidson County  37207.0
# 58 -86.778513             1.0  range_interpolation  Davidson County  37201.0
# 59 -86.796756             1.0              rooftop  Davidson County  37208.0
# 60 -86.740288             0.9  range_interpolation  Davidson County  37211.0
# 61 -86.798286             1.0              rooftop  Davidson County  37212.0
#
#                Buffer_Geometry  \
# 0   POINT (-86.34936 35.85856)
# 1   POINT (-86.84360 36.15230)
# 2   POINT (-86.34936 35.85856)
# 3   POINT (-86.81852 36.12879)
# 4   POINT (-86.75566 36.14476)
# ..                         ...
# 57  POINT (-86.76518 36.18980)
# 58  POINT (-86.77851 36.16393)
# 59  POINT (-86.79676 36.18170)
# 60  POINT (-86.74029 36.09256)
# 61  POINT (-86.79829 36.11696)
#
#                                           Buffer_Zone
# 0   POLYGON ((-86.34926 35.85856, -86.34926 35.858...
# 1   POLYGON ((-86.84350 36.15230, -86.84350 36.152...
# 2   POLYGON ((-86.34926 35.85856, -86.34926 35.858...
# 3   POLYGON ((-86.81842 36.12879, -86.81842 36.128...
# 4   POLYGON ((-86.75556 36.14476, -86.75556 36.144...
# ..                                                ...
# 57  POLYGON ((-86.76508 36.18980, -86.76508 36.189...
# 58  POLYGON ((-86.77841 36.16393, -86.77841 36.163...
# 59  POLYGON ((-86.79666 36.18170, -86.79666 36.181...
# 60  POLYGON ((-86.74019 36.09256, -86.74019 36.092...
# 61  POLYGON ((-86.79819 36.11696, -86.79819 36.116...
#
# [62 rows x 15 columns]

# %%
center = [36.16784, -86.78166]
nashville_buffer_map = folium.Map(location = center, zoom_start=11)

# %%
folium.GeoJson(clusters_locations_geodf['Buffer_Zone']).add_to(nashville_buffer_map)

# %%
nashville_buffer_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Look at some Folium Maps

# %% [markdown]
# ## Starting with just looking at all the clusters

# %% [markdown]
# COVID Icon - Icons made by <a href="https://www.flaticon.com/authors/freepik" title="Freepik">Freepik</a> from <a href="https://www.flaticon.com/" title="Flaticon"> www.flaticon.com</a>

# %%
clusters_locations
# Out:
#                                  Cluster Name                  Street  \
# 0                          Vanderbilt Parties                     NaN
# 1                    Event at Clementine Hall   4710 Charlotte Avenue
# 2                           Religious Retreat                     NaN
# 3         The Health Center at Richland Place    504 Elmington Avenue
# 4       Trevecca Center for Rehab and Healing   329 Murfreesboro Pike
# ..                                        ...                     ...
# 57                   One Stone Church Service      1101 Stainback Ave
# 58                               Miss Kelli's      207 Printers Alley
# 59  Nashville Rescue Mission - Women's Campus  1716 Rosa L Parks Blvd
# 60                      Link Systems Electric          444 McNally Dr
# 61                         Iron Tribe Belmont       3201 Belmont Blvd
#
#          City State      Facility Type Cluster Start Date  # Cases   Latitude  \
# 0         NaN    TN   Social Gathering            3/11/20       49  35.858564
# 1   Nashville    TN   Social Gathering            3/14/20       23  36.152300
# 2         NaN    TN   Social Gathering            3/25/20       18  35.858564
# 3   Nashville    TN               LTCF             4/3/20       47  36.128791
# 4   Nashville    TN               LTCF             4/4/20      102  36.144764
# ..        ...   ...                ...                ...      ...        ...
# 57  Nashville    TN             Church            9/22/20       10  36.189795
# 58  Nashville    TN                Bar            10/1/20       14  36.163931
# 59  Nashville    TN  Congregate Living            10/1/20       70  36.181699
# 60  Nashville    TN              Other           10/16/20       12  36.092556
# 61  Nashville    TN                Gym           10/20/20       14  36.116961
#
#     Longitude  Accuracy Score        Accuracy Type           County      Zip  \
# 0  -86.349357             1.0                state              NaN      NaN
# 1  -86.843597             1.0  range_interpolation  Davidson County  37209.0
# 2  -86.349357             1.0                state              NaN      NaN
# 3  -86.818522             1.0  range_interpolation  Davidson County  37205.0
# 4  -86.755659             1.0              rooftop  Davidson County  37210.0
# ..        ...             ...                  ...              ...      ...
# 57 -86.765180             1.0  range_interpolation  Davidson County  37207.0
# 58 -86.778513             1.0  range_interpolation  Davidson County  37201.0
# 59 -86.796756             1.0              rooftop  Davidson County  37208.0
# 60 -86.740288             0.9  range_interpolation  Davidson County  37211.0
# 61 -86.798286             1.0              rooftop  Davidson County  37212.0
#
#                          Buffer_Geometry                    geometry
# 0           POINT (-86.349357 35.858564)  POINT (-86.34936 35.85856)
# 1             POINT (-86.843597 36.1523)  POINT (-86.84360 36.15230)
# 2           POINT (-86.349357 35.858564)  POINT (-86.34936 35.85856)
# 3           POINT (-86.818522 36.128791)  POINT (-86.81852 36.12879)
# 4   POINT (-86.75565899999999 36.144764)  POINT (-86.75566 36.14476)
# ..                                   ...                         ...
# 57           POINT (-86.76518 36.189795)  POINT (-86.76518 36.18980)
# 58          POINT (-86.778513 36.163931)  POINT (-86.77851 36.16393)
# 59          POINT (-86.796756 36.181699)  POINT (-86.79676 36.18170)
# 60  POINT (-86.74028800000001 36.092556)  POINT (-86.74029 36.09256)
# 61          POINT (-86.798286 36.116961)  POINT (-86.79829 36.11696)
#
# [62 rows x 15 columns]

# %%
center = [36.16784, -86.78166]
nashville_presentation_map_1 = folium.Map(location = center, zoom_start=11)

# %%
def color_producer(elevation):
    if elevation < 1000:
        return 'green'
    elif 1000 <= elevation < 3000:
        return 'orange'
    else:
        return 'red'
map = folium.Map(location=[38.58, -99.09], zoom_start=6, tiles="Mapbox Bright")
fg = folium.FeatureGroup(name="My Map")
for lt, ln, el in zip(lat, lon, elev):
    fg.add_child(folium.CircleMarker(location=[lt, ln], radius = 6, popup=str(el)+" m",
    fill_color=color_producer(el), color = 'grey', fill_opacity=0.7))
map.add_child(fg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-0967fdbed03d> in <module>
#       8 map = folium.Map(location=[38.58, -99.09], zoom_start=6, tiles="Mapbox Bright")
#       9 fg = folium.FeatureGroup(name="My Map")
# ---> 10 for lt, ln, el in zip(lat, lon, elev):
#      11     fg.add_child(folium.CircleMarker(location=[lt, ln], radius = 6, popup=str(el)+" m",
#      12     fill_color=color_producer(el), color = 'grey', fill_opacity=0.7))
#
# NameError: name 'lat' is not defined

# %%
def color_producer(elevation):
    if elevation < 1000:
        return 'green'
    elif 1000 <= elevation < 3000:
        return 'orange'
    else:
        return 'red'

for row_index, row_values in clusters_locations.iterrows():
    loc = [row_values['Latitude'], row_values['Longitude']]
    pop = str(row_values['Cluster Name'])
    rad = row_values['# Cases'] * 5
    marker = folium.Circle(
        location = loc,
        radius = rad,
        fill = True,
        fill_color = 'red',
        color = 'red',
        popup = folium.Popup(pop,
                     min_width=200,
                     max_width=500))
    
    marker.add_to(nashville_presentation_map_1)
    
nashville_presentation_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
center = [36.16784, -86.78166]
nashville_cluster_map = folium.Map(location = center, zoom_start=11)

# %%
for row_index, row_values in clusters_locations.iterrows():
    loc = [row_values['Latitude'], row_values['Longitude']]
    pop = str(row_values['Cluster Name'])
    icon = folium.features.CustomIcon('covid4.png')
    marker = folium.Marker(
        icon = icon,
        location = loc,
        popup = folium.Popup(pop,
                     min_width=200,
                     max_width=500))
    
    marker.add_to(nashville_cluster_map)
    
nashville_cluster_map

# %% [markdown]
# ## Look at all reports
# ### Start by creating DataFrame without repeating coordinate locations

# %%
hub_covid_violations_df.head()

# %%
hub_covid_violations_df['Coordinates'] = list(zip(hub_covid_violations_df.Latitude, hub_covid_violations_df.Longitude))

# %%
hub_covid_map_df = hub_covid_violations_df.groupby('Coordinates').count()

# %%
center = [36.1672, -86.7816]
nashville_report_map = folium.Map(location = center, zoom_start=11)

# %%
#for row_index, row_values in hub_covid_violations_df[
    (hub_covid_violations_df['City'].notna()) & 
    (hub_covid_violations_df['Latitude'].notna())].iterrows():
    
    loc = [row_values['Latitude'], row_values['Longitude']]
    #pop = str(row_values['Cluster Name'])
    icon = folium.features.CustomIcon('covid4.png')
    marker = folium.Marker(
        icon = icon,
        location = loc)
        #popup = folium.Popup(pop,
                     #min_width=200,
                     #max_width=500))
    
    marker.add_to(nashville_report_map)
    
nashville_report_map

# %%
center = [36.16784, -86.78166]
nashville_covid_map = folium.Map(location = center, zoom_start=11)

# %%
for row_index, row_values in clusters_violations.iterrows():
    loc = [row_values['Latitude'], row_values['Longitude']]
    pop = str(row_values['Cluster Name'])
    icon = folium.features.CustomIcon('covid4.png')
    marker = folium.Marker(
        icon = icon,
        location = loc,
        popup = folium.Popup(pop,
                     min_width=200,
                     max_width=500))
    
    marker.add_to(nashville_covid_map)

# %%
nashville_covid_map

# %% [markdown]
# Loser's looks like it's located in the wrong spot - so it may not be correct for a cluster??

# %% [markdown]
# ## Create a circle arounch each cluster, checking location matches that way

# %%
clusters_violations_geo['Cluster_Geometry']

# %%
for r in clusters_violations_geo:
    p = r['Cluster_Geometry']
    n_points = 20
    d = 10 # meters
    angles = np.linspace(0, 360, n_points)
    r['Cluster_Polygon'] = geog.propagate(p, angles, d)

# %%
n_points = 20
d = 10 * 1000  # meters
angles = np.linspace(0, 360, n_points)
polygon = geog.propagate(p, angles, d)
print(json.dumps(shapely.geometry.mapping(shapely.geometry.Polygon(polygon))))

# %% [markdown]
# ## Import JSON files with business info

# %%
business_glob = glob.glob('../data/google_places_results/*.json')

# %%
jsons_list = []
for j in business_glob:
    with open(j) as result_file:
        jsons_list.append(json.load(result_file))

# %%
jsons_list[0][0]['results']

# %%
#Same as business_glob, but with Jason's code
json_files = glob.glob('../data/google_places_results/results_*.json')

# %%
def process_json_file(filename):
    with open(filename) as result_file:
        results_json = json.load(result_file)
        results_json_list = []
        for result_json in results_json:
            for result_json_result in result_json['results']:
                result_json_result['orig_mapped_location'] = result_json['mapped_location']
                result_json_result['orig_address'] = result_json['address']
                results_json_list.append(result_json_result)
        return pd.DataFrame(results_json_list)

# %%
frames = [process_json_file(file_path) for file_path in json_files]

# %%
frames

# %%
all_places_results = pd.concat(frames)

# %%
all_places_results.iloc[2]

# %%
def matcher(column1, column2):
    names_array=[]
    ratio_array=[]    
    if column1 in column2:
        return 100
    else:   
        return fuzz.partial_ratio(column1,column2)

# %%
all_places_results['match_ratio'] = all_places_results.apply(
    lambda x: matcher(x['vicinity'].split(',')[0], x['orig_address'].split(',')[0]), axis=1)

# %%
all_places_results

# %%
for addr, grp in all_places_results[all_places_results['match_ratio'] > 93].groupby('orig_address'):
    print(addr)
    print(grp[grp.match_ratio == grp.match_ratio.max()].iloc[0])
    print('='*30)

# %%
# Checking out Veronica's coding:

# Create an empty dataframe with the columns we want
column_names = ['mapped_location', 'address']
result_addresses = pd.DataFrame(columns = column_names)
# Go through and open each json results file
for file in list(glob.glob('../data/google_places_results/*.json')):
    with open(file) as fi:
        result = json.load(fi)
# Write the contents of the 'results' field to a dataframe       
        google_results = pd.json_normalize(result)
# Clean up the dataframe columns
        google_results = google_results.drop(['results'], axis = 1)
        google_results.columns = ['mapped_location', 'address']
# Append the contents of each json file to the results dataframe
        result_addresses = result_addresses.append(google_results)

# %%
result_addresses.head()

# %%
with open('data/example.json', "r") as fi:
    person = json.load(fi)

# %%
businesses[0]

# %%
with open('../data/google_places_results/results_32.json', "r") as fi:
    person = json.load(fi)

# %%
print(pd.DataFrame(person[0]['results'][0].T)

# %%
person[0]['results'][0].keys()

# %%
pd.DataFrame(person[0]['results'][0].T)

# %%
person[0]['results']
