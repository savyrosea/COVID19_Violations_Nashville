# %%
import glob
import json
import pandas as pd
from collections import Counter
from fuzzywuzzy import fuzz
import plotly.express as px

# %%
json_files = glob.glob('../data/google_places_results/results_*.json')

# %%
def process_json_file(filename):
    with open(filename) as result_file:
        results_json = json.load(result_file)
        results_json_list = []
        for result_json in results_json:
            for result_json_result in result_json['results']:
                result_json_result['orig_mapped_location'] = result_json['mapped_location']
                result_json_result['orig_address'] = result_json['address']
                results_json_list.append(result_json_result)
        return pd.DataFrame(results_json_list)

# %%
#frames is a list of dfs
frames = [process_json_file(file_path) for file_path in json_files]

# %%
#combining all the dfs
all_places_results = pd.concat(frames)

# %%
#taking a look
all_places_results.head(2)
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 36.0685457, 'lng': -86.68...
# 1     OPERATIONAL  {'location': {'lat': 36.0684753, 'lng': -86.68...
#
#                                                 icon            name  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...    Los Paisanos
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...  Sun Hair Salon
#
#         opening_hours                     place_id  \
# 0  {'open_now': True}  ChIJ7w-yGUFuZIgR7rrQpRfCGgw
# 1  {'open_now': True}  ChIJlfxUC0FuZIgRa8G6Arf-BW8
#
#                                            plus_code  rating  \
# 0  {'compound_code': '3898+CC Nashville, TN, USA'...     4.2
# 1  {'compound_code': '3898+9C Nashville, TN, USA'...     4.6
#
#                      reference   scope  \
# 0  ChIJ7w-yGUFuZIgR7rrQpRfCGgw  GOOGLE
# 1  ChIJlfxUC0FuZIgRa8G6Arf-BW8  GOOGLE
#
#                                                types  user_ratings_total  \
# 0  [night_club, bar, point_of_interest, establish...                 6.0
# 1  [beauty_salon, hair_care, point_of_interest, e...                50.0
#
#                      vicinity       orig_mapped_location  \
# 0  2045 Antioch Pike, Antioch  (36.0685457, -86.6838975)
# 1  2049 Antioch Pike, Antioch  (36.0685457, -86.6838975)
#
#                  orig_address  \
# 0  2045 Antioch Pike, Antioch
# 1  2045 Antioch Pike, Antioch
#
#                                               photos  price_level  \
# 0                                                NaN          NaN
# 1  [{'height': 3024, 'html_attributions': ['<a hr...          NaN
#
#   permanently_closed
# 0                NaN
# 1                NaN

# %%
def matcher(column1, column2):
    names_array=[]
    ratio_array=[]    
    if column1 in column2:
        return 100
    else:   
        return fuzz.partial_ratio(column1,column2)

# %%
all_places_results['match_ratio'] = all_places_results.apply(
    lambda x: matcher(x['vicinity'].split(',')[0], x['orig_address'].split(',')[0]), axis=1)

# %%
all_places_results = all_places_results[all_places_results['match_ratio'] > 93]

# %% [markdown]
# for addr, grp in all_places_results[all_places_results['match_ratio'] > 93].groupby('orig_address'):
#     print(addr)
#     print(grp[grp.match_ratio == grp.match_ratio.max()].iloc[0])
#     print('='*30)

# %%
types_list = all_places_results['types'].to_list()

# %% [markdown]
# ## removing restaurant or finance if already tagged

# %%
rest = ['supermarket','meal_delivery', 'grocery_or_supermarket','cafe','meal_takeaway','bakery', 'liquor_store', 'convenience_store']
fin = ['accounting', 'bank', 'atm']

for i in types_list:
    holder = 0
    for j in i:
        if ('restaurant' in i) & (j in rest) & (holder == 0):
            i.remove('restaurant')
            holder = 1
        if ('finance' in i) & (j in fin) & (holder == 0):
            i.remove('finance')
            holder = 1

# %%
types_list
# Out:
# [['night_club', 'bar', 'point_of_interest', 'establishment'],
#  ['beauty_salon', 'hair_care', 'point_of_interest', 'establishment'],
#  ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['jewelry_store', 'point_of_interest', 'store', 'establishment'],
#  ['convenience_store',
#   'cafe',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['convenience_store',
#   'bakery',
#   'cafe',
#   'liquor_store',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['food', 'point_of_interest', 'store', 'establishment'],
#  ['gas_station', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['shoe_store', 'point_of_interest', 'store', 'establishment'],
#  ['general_contractor',
#   'real_estate_agency',
#   'point_of_interest',
#   'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['bar', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['bar', 'point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['church', 'place_of_worship', 'point_of_interest', 'establishment'],
#  ['bank', 'point_of_interest', 'establishment'],
#  ['atm', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['store', 'point_of_interest', 'establishment'],
#  ['park', 'point_of_interest', 'establishment'],
#  ['park', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['gas_station', 'point_of_interest', 'establishment'],
#  ['furniture_store',
#   'home_goods_store',
#   'general_contractor',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['furniture_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['atm', 'point_of_interest', 'establishment'],
#  ['bank', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['museum', 'point_of_interest', 'establishment'],
#  ['courthouse', 'point_of_interest', 'establishment'],
#  ['local_government_office', 'point_of_interest', 'establishment'],
#  ['local_government_office', 'point_of_interest', 'establishment'],
#  ['local_government_office', 'point_of_interest', 'establishment'],
#  ['bar', 'point_of_interest', 'establishment'],
#  ['jewelry_store', 'point_of_interest', 'store', 'establishment'],
#  ['tourist_attraction', 'point_of_interest', 'establishment'],
#  ['jewelry_store', 'point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#  ['meal_takeaway', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['home_goods_store', 'point_of_interest', 'store', 'establishment'],
#  ['gas_station',
#   'atm',
#   'car_wash',
#   'convenience_store',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['convenience_store', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['convenience_store', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['convenience_store',
#   'cafe',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['convenience_store',
#   'cafe',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['hair_care', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['beauty_salon', 'point_of_interest', 'establishment'],
#  ['hair_care', 'point_of_interest', 'establishment'],
#  ['spa', 'health', 'point_of_interest', 'establishment'],
#  ['veterinary_care', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'clothing_store', 'store', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['painter',
#   'electrician',
#   'plumber',
#   'general_contractor',
#   'point_of_interest',
#   'establishment'],
#  ['hardware_store',
#   'furniture_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'store', 'establishment'],
#  ['gas_station', 'point_of_interest', 'establishment'],
#  ['hair_care', 'point_of_interest', 'store', 'establishment'],
#  ['atm', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['night_club',
#   'bar',
#   'restaurant',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['meal_takeaway', 'food', 'point_of_interest', 'establishment'],
#  ['cafe',
#   'bakery',
#   'meal_takeaway',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['gas_station',
#   'convenience_store',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['parking', 'premise', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['physiotherapist', 'health', 'point_of_interest', 'establishment'],
#  ['physiotherapist', 'doctor', 'health', 'point_of_interest', 'establishment'],
#  ['physiotherapist', 'health', 'point_of_interest', 'establishment'],
#  ['grocery_or_supermarket',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['locksmith', 'point_of_interest', 'establishment'],
#  ['spa', 'point_of_interest', 'establishment'],
#  ['beauty_salon', 'point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['beauty_salon', 'point_of_interest', 'establishment'],
#  ['hair_care', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['lawyer', 'point_of_interest', 'establishment'],
#  ['lawyer', 'point_of_interest', 'establishment'],
#  ['atm', 'point_of_interest', 'store', 'establishment'],
#  ['liquor_store', 'point_of_interest', 'store', 'establishment'],
#  ['liquor_store', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['meal_delivery', 'food', 'point_of_interest', 'establishment'],
#  ['meal_takeaway', 'food', 'point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['jewelry_store', 'finance', 'point_of_interest', 'store', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['meal_takeaway', 'bar', 'food', 'point_of_interest', 'establishment'],
#  ['electronics_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['car_repair', 'point_of_interest', 'store', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['gym', 'spa', 'health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['electronics_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['electronics_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['beauty_salon', 'hair_care', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['car_wash', 'point_of_interest', 'establishment'],
#  ['car_repair', 'point_of_interest', 'store', 'establishment'],
#  ['car_repair', 'point_of_interest', 'store', 'establishment'],
#  ['electronics_store',
#   'car_repair',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['atm', 'point_of_interest', 'store', 'establishment'],
#  ['liquor_store', 'point_of_interest', 'store', 'establishment'],
#  ['liquor_store', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['university', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['bank', 'atm', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['electronics_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['bakery', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['school', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['electronics_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['bakery',
#   'meal_takeaway',
#   'cafe',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['car_wash', 'point_of_interest', 'establishment'],
#  ['car_wash', 'point_of_interest', 'establishment'],
#  ['car_wash', 'point_of_interest', 'establishment'],
#  ['spa', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['bar', 'point_of_interest', 'establishment'],
#  ['bar', 'point_of_interest', 'establishment'],
#  ['shopping_mall', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['school', 'point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['atm', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['electronics_store', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['gym', 'health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['dentist', 'health', 'point_of_interest', 'establishment'],
#  ['furniture_store',
#   'home_goods_store',
#   'general_contractor',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['hardware_store',
#   'furniture_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['convenience_store', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['bar', 'point_of_interest', 'establishment'],
#  ['insurance_agency', 'point_of_interest', 'establishment'],
#  ['real_estate_agency', 'point_of_interest', 'establishment'],
#  ['real_estate_agency', 'point_of_interest', 'establishment'],
#  ['real_estate_agency', 'point_of_interest', 'establishment'],
#  ['real_estate_agency', 'point_of_interest', 'establishment'],
#  ['grocery_or_supermarket',
#   'florist',
#   'supermarket',
#   'liquor_store',
#   'food',
#   'health',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['furniture_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'clothing_store', 'store', 'establishment'],
#  ['florist', 'point_of_interest', 'store', 'establishment'],
#  ['laundry',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['plumber', 'point_of_interest', 'establishment'],
#  ['lawyer', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['grocery_or_supermarket',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['home_goods_store', 'point_of_interest', 'store', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['tourist_attraction', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['parking', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['beauty_salon', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'clothing_store', 'store', 'establishment'],
#  ['insurance_agency', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['home_goods_store', 'point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['library', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['car_repair', 'point_of_interest', 'store', 'establishment'],
#  ['plumber', 'general_contractor', 'point_of_interest', 'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['meal_delivery',
#   'meal_takeaway',
#   'food',
#   'point_of_interest',
#   'establishment'],
#  ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['electronics_store', 'point_of_interest', 'store', 'establishment'],
#  ['primary_school', 'school', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['bank', 'atm', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['university', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['beauty_salon', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['travel_agency', 'point_of_interest', 'establishment'],
#  ['parking', 'point_of_interest', 'establishment'],
#  ['bakery', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['electronics_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['atm', 'point_of_interest', 'establishment'],
#  ['convenience_store', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['school', 'point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['meal_takeaway', 'bar', 'food', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['hair_care', 'health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['car_repair', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['parking', 'point_of_interest', 'establishment'],
#  ['night_club', 'bar', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['atm', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['gym', 'health', 'point_of_interest', 'establishment'],
#  ['primary_school', 'school', 'point_of_interest', 'establishment'],
#  ['school', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['physiotherapist', 'health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['gas_station', 'point_of_interest', 'establishment'],
#  ['convenience_store',
#   'gas_station',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['hardware_store',
#   'furniture_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['furniture_store',
#   'home_goods_store',
#   'general_contractor',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['painter',
#   'electrician',
#   'plumber',
#   'general_contractor',
#   'point_of_interest',
#   'establishment'],
#  ['real_estate_agency', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['bank', 'atm', 'point_of_interest', 'establishment'],
#  ['lawyer', 'point_of_interest', 'establishment'],
#  ['food', 'point_of_interest', 'store', 'establishment'],
#  ['lawyer', 'point_of_interest', 'establishment'],
#  ['lawyer', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['car_repair', 'point_of_interest', 'store', 'establishment'],
#  ['home_goods_store', 'point_of_interest', 'store', 'establishment'],
#  ['home_goods_store',
#   'general_contractor',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['meal_takeaway', 'bar', 'food', 'point_of_interest', 'establishment'],
#  ['veterinary_care', 'point_of_interest', 'store', 'establishment'],
#  ['veterinary_care', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['gas_station',
#   'atm',
#   'convenience_store',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['gas_station', 'car_repair', 'point_of_interest', 'establishment'],
#  ['convenience_store', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['gas_station',
#   'atm',
#   'convenience_store',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['beauty_salon', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['beauty_salon', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['liquor_store', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['beauty_salon', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['beauty_salon', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['lawyer', 'point_of_interest', 'establishment'],
#  ['hardware_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['florist', 'point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['university', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['insurance_agency', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['grocery_or_supermarket',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['physiotherapist', 'health', 'point_of_interest', 'establishment'],
#  ['pharmacy', 'health', 'point_of_interest', 'store', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['gym', 'spa', 'health', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['movie_rental', 'point_of_interest', 'store', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['atm', 'point_of_interest', 'establishment'],
#  ['bank', 'atm', 'point_of_interest', 'establishment'],
#  ['car_repair', 'storage', 'point_of_interest', 'store', 'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['funeral_home', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['atm', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['locksmith', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['bar', 'point_of_interest', 'establishment'],
#  ['food', 'point_of_interest', 'establishment'],
#  ['meal_takeaway', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['hair_care', 'health', 'point_of_interest', 'establishment'],
#  ['hair_care', 'health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['real_estate_agency', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['park', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['park', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['bar',
#   'night_club',
#   'restaurant',
#   'food',
#   'point_of_interest',
#   'establishment'],
#  ['car_repair', 'point_of_interest', 'establishment'],
#  ['car_repair', 'point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['tourist_attraction', 'point_of_interest', 'establishment'],
#  ['parking', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['bank', 'point_of_interest', 'establishment'],
#  ['gas_station', 'point_of_interest', 'establishment'],
#  ['meal_takeaway', 'food', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['car_repair', 'point_of_interest', 'store', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['gym', 'health', 'point_of_interest', 'establishment'],
#  ['meal_takeaway', 'food', 'point_of_interest', 'establishment'],
#  ['shoe_store',
#   'shopping_mall',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['furniture_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['grocery_or_supermarket',
#   'supermarket',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['food', 'point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['electronics_store', 'point_of_interest', 'store', 'establishment'],
#  ['hair_care', 'health', 'point_of_interest', 'establishment'],
#  ['hair_care', 'health', 'point_of_interest', 'establishment'],
#  ['electronics_store',
#   'car_repair',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['car_repair', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['storage', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['bakery', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['electronics_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['real_estate_agency', 'point_of_interest', 'establishment'],
#  ['meal_takeaway', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['art_gallery', 'museum', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['local_government_office', 'point_of_interest', 'establishment'],
#  ['local_government_office', 'point_of_interest', 'establishment'],
#  ['accounting',
#   'local_government_office',
#   'point_of_interest',
#   'establishment'],
#  ['local_government_office', 'point_of_interest', 'establishment'],
#  ['local_government_office', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['school', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['post_office',
#   'finance',
#   'local_government_office',
#   'point_of_interest',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['school', 'point_of_interest', 'establishment'],
#  ['hair_care', 'point_of_interest', 'establishment'],
#  ['dentist', 'health', 'point_of_interest', 'establishment'],
#  ['meal_takeaway', 'food', 'point_of_interest', 'establishment'],
#  ['dentist', 'health', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['car_repair', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['home_goods_store', 'point_of_interest', 'store', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['laundry', 'point_of_interest', 'clothing_store', 'store', 'establishment'],
#  ['grocery_or_supermarket',
#   'supermarket',
#   'food',
#   'health',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['hair_care', 'health', 'point_of_interest', 'establishment'],
#  ['beauty_salon', 'point_of_interest', 'establishment'],
#  ['furniture_store',
#   'home_goods_store',
#   'general_contractor',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['store', 'point_of_interest', 'establishment'],
#  ['gym', 'health', 'point_of_interest', 'establishment'],
#  ['pharmacy', 'health', 'point_of_interest', 'store', 'establishment'],
#  ['pharmacy', 'health', 'point_of_interest', 'store', 'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['school', 'point_of_interest', 'establishment'],
#  ['shoe_store',
#   'point_of_interest',
#   'clothing_store',
#   'store',
#   'establishment'],
#  ['general_contractor', 'point_of_interest', 'store', 'establishment'],
#  ['beauty_salon', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['parking', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['real_estate_agency', 'travel_agency', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['car_dealer', 'point_of_interest', 'store', 'establishment'],
#  ['car_dealer', 'point_of_interest', 'store', 'establishment'],
#  ['car_repair', 'point_of_interest', 'store', 'establishment'],
#  ['electronics_store',
#   'car_repair',
#   'furniture_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['meal_takeaway', 'food', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#  ['gym', 'health', 'point_of_interest', 'establishment'],
#  ['school', 'point_of_interest', 'establishment'],
#  ['laundry', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['car_repair', 'point_of_interest', 'store', 'establishment'],
#  ['meal_delivery',
#   'meal_takeaway',
#   'food',
#   'point_of_interest',
#   'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['tourist_attraction',
#   'museum',
#   'park',
#   'point_of_interest',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['parking', 'point_of_interest', 'establishment'],
#  ['tourist_attraction', 'park', 'point_of_interest', 'establishment'],
#  ['tourist_attraction', 'park', 'point_of_interest', 'establishment'],
#  ['car_repair', 'storage', 'point_of_interest', 'store', 'establishment'],
#  ['meal_delivery',
#   'meal_takeaway',
#   'food',
#   'point_of_interest',
#   'establishment'],
#  ['hair_care', 'health', 'point_of_interest', 'establishment'],
#  ['beauty_salon', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['moving_company', 'point_of_interest', 'establishment'],
#  ['electrician',
#   'general_contractor',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['bar', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['bus_station', 'transit_station', 'point_of_interest', 'establishment'],
#  ['bus_station', 'transit_station', 'point_of_interest', 'establishment'],
#  ['laundry', 'point_of_interest', 'establishment'],
#  ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['liquor_store', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['beauty_salon', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['courthouse',
#   'local_government_office',
#   'point_of_interest',
#   'establishment'],
#  ['local_government_office', 'point_of_interest', 'establishment'],
#  ['local_government_office', 'point_of_interest', 'establishment'],
#  ['local_government_office', 'point_of_interest', 'establishment'],
#  ['courthouse', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['car_repair', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['night_club', 'point_of_interest', 'establishment'],
#  ['food', 'point_of_interest', 'establishment'],
#  ['hair_care', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['liquor_store', 'point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#  ['night_club', 'bar', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['meal_takeaway', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['gym', 'health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'clothing_store', 'store', 'establishment'],
#  ['hair_care', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['moving_company', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['insurance_agency', 'point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['dentist', 'health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['bar', 'point_of_interest', 'establishment'],
#  ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['museum', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['lawyer', 'accounting', 'point_of_interest', 'establishment'],
#  ['gas_station',
#   'convenience_store',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['atm', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['car_repair', 'point_of_interest', 'store', 'establishment'],
#  ['gym', 'health', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['electronics_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['meal_takeaway', 'food', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['florist', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['meal_delivery',
#   'meal_takeaway',
#   'food',
#   'point_of_interest',
#   'establishment'],
#  ['physiotherapist', 'health', 'point_of_interest', 'establishment'],
#  ['beauty_salon', 'point_of_interest', 'establishment'],
#  ['food', 'point_of_interest', 'store', 'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['beauty_salon',
#   'hair_care',
#   'spa',
#   'health',
#   'point_of_interest',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['beauty_salon', 'hair_care', 'point_of_interest', 'establishment'],
#  ['real_estate_agency', 'travel_agency', 'point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['car_repair', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['car_repair', 'point_of_interest', 'store', 'establishment'],
#  ['store', 'point_of_interest', 'establishment'],
#  ['bakery', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['laundry', 'point_of_interest', 'establishment'],
#  ['florist', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#  ['real_estate_agency', 'travel_agency', 'point_of_interest', 'establishment'],
#  ['shoe_store',
#   'point_of_interest',
#   'clothing_store',
#   'store',
#   'establishment'],
#  ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['parking', 'point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['grocery_or_supermarket',
#   'home_goods_store',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['car_repair', 'point_of_interest', 'establishment'],
#  ['furniture_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['real_estate_agency', 'point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#  ['laundry', 'point_of_interest', 'establishment'],
#  ['laundry', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['church', 'place_of_worship', 'point_of_interest', 'establishment'],
#  ['cafe', 'bar', 'food', 'point_of_interest', 'establishment'],
#  ['bus_station', 'transit_station', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['meal_takeaway', 'food', 'point_of_interest', 'establishment'],
#  ['meal_takeaway', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['jewelry_store', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['art_gallery', 'painter', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['school', 'point_of_interest', 'establishment'],
#  ['real_estate_agency', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['beauty_salon', 'hair_care', 'point_of_interest', 'establishment'],
#  ['bank', 'point_of_interest', 'establishment'],
#  ['electronics_store',
#   'home_goods_store',
#   'school',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['home_goods_store',
#   'general_contractor',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['gym', 'health', 'point_of_interest', 'establishment'],
#  ['storage', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['art_gallery', 'point_of_interest', 'establishment'],
#  ['insurance_agency', 'point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['home_goods_store', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['furniture_store',
#   'home_goods_store',
#   'general_contractor',
#   'point_of_interest',
#   'clothing_store',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'clothing_store', 'store', 'establishment'],
#  ['food', 'point_of_interest', 'store', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['spa', 'health', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['beauty_salon', 'point_of_interest', 'establishment'],
#  ['atm', 'point_of_interest', 'establishment'],
#  ['laundry', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['grocery_or_supermarket',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['local_government_office', 'point_of_interest', 'establishment'],
#  ['bar', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['meal_delivery',
#   'meal_takeaway',
#   'food',
#   'point_of_interest',
#   'establishment'],
#  ['church',
#   'place_of_worship',
#   'school',
#   'point_of_interest',
#   'establishment'],
#  ['church', 'place_of_worship', 'point_of_interest', 'establishment'],
#  ['primary_school',
#   'secondary_school',
#   'school',
#   'point_of_interest',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['accounting', 'point_of_interest', 'establishment'],
#  ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['meal_takeaway', 'food', 'point_of_interest', 'establishment'],
#  ['doctor', 'spa', 'health', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['bar', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['bus_station', 'transit_station', 'point_of_interest', 'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['meal_takeaway', 'food', 'point_of_interest', 'establishment'],
#  ['shopping_mall', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['laundry', 'point_of_interest', 'establishment'],
#  ['food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['grocery_or_supermarket',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['locksmith', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['pharmacy',
#   'hospital',
#   'doctor',
#   'health',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['pharmacy', 'health', 'point_of_interest', 'store', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['hardware_store',
#   'furniture_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['locksmith', 'point_of_interest', 'establishment'],
#  ['finance', 'car_dealer', 'point_of_interest', 'store', 'establishment'],
#  ['car_repair', 'point_of_interest', 'establishment'],
#  ['car_repair', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['art_gallery', 'point_of_interest', 'establishment'],
#  ['bar', 'point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['real_estate_agency', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['hardware_store', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['hospital', 'health', 'point_of_interest', 'establishment'],
#  ['car_repair', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['insurance_agency', 'point_of_interest', 'establishment'],
#  ['gas_station', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['accounting', 'point_of_interest', 'establishment'],
#  ['atm', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ['car_repair', 'point_of_interest', 'store', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['hair_care', 'point_of_interest', 'establishment'],
#  ['place_of_worship', 'point_of_interest', 'establishment'],
#  ['school', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['school', 'point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['bus_station', 'transit_station', 'point_of_interest', 'establishment'],
#  ['car_dealer', 'point_of_interest', 'store', 'establishment'],
#  ['accounting', 'point_of_interest', 'establishment'],
#  ['insurance_agency', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['lodging', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['secondary_school', 'school', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['dentist', 'health', 'point_of_interest', 'establishment'],
#  ['general_contractor', 'health', 'point_of_interest', 'establishment'],
#  ['painter',
#   'electrician',
#   'plumber',
#   'general_contractor',
#   'point_of_interest',
#   'establishment'],
#  ['hardware_store',
#   'furniture_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'store', 'establishment'],
#  ['school', 'point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['secondary_school', 'school', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['church', 'place_of_worship', 'point_of_interest', 'establishment'],
#  ['church', 'place_of_worship', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['church', 'place_of_worship', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['electrician', 'general_contractor', 'point_of_interest', 'establishment'],
#  ['storage', 'food', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['home_goods_store',
#   'storage',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['food', 'point_of_interest', 'establishment'],
#  ['real_estate_agency', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['real_estate_agency', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['park', 'point_of_interest', 'establishment'],
#  ['travel_agency', 'point_of_interest', 'establishment'],
#  ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  ['moving_company', 'point_of_interest', 'establishment'],
#  ['shoe_store', 'point_of_interest', 'store', 'establishment'],
#  ['point_of_interest', 'clothing_store', 'store', 'establishment'],
#  ['tourist_attraction', 'point_of_interest', 'establishment'],
#  ['electronics_store',
#   'home_goods_store',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['church', 'place_of_worship', 'point_of_interest', 'establishment'],
#  ['transit_station', 'point_of_interest', 'establishment'],
#  ['church', 'place_of_worship', 'point_of_interest', 'establishment'],
#  ['tourist_attraction', 'park', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['local_government_office', 'point_of_interest', 'establishment'],
#  ['veterinary_care', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['insurance_agency', 'point_of_interest', 'establishment'],
#  ['secondary_school', 'school', 'point_of_interest', 'establishment'],
#  ['general_contractor', 'point_of_interest', 'establishment'],
#  ['real_estate_agency', 'travel_agency', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['doctor', 'health', 'point_of_interest', 'establishment'],
#  ['gas_station',
#   'convenience_store',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['health', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['tourist_attraction', 'park', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['local_government_office', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['church', 'place_of_worship', 'point_of_interest', 'establishment'],
#  ['church', 'place_of_worship', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['hair_care', 'health', 'point_of_interest', 'establishment'],
#  ['painter', 'point_of_interest', 'establishment'],
#  ['point_of_interest', 'establishment'],
#  ['home_goods_store', 'point_of_interest', 'store', 'establishment'],
#  ['supermarket',
#   'grocery_or_supermarket',
#   'finance',
#   'food',
#   'point_of_interest',
#   'store',
#   'establishment'],
#  ['finance', 'point_of_interest', 'establishment'],
#  ...]

# %%
#flattening the list
types_list_flat = [item for sublist in types_list for item in sublist]

# %%
types_list_flat
# Out:
# ['night_club',
#  'bar',
#  'point_of_interest',
#  'establishment',
#  'beauty_salon',
#  'hair_care',
#  'point_of_interest',
#  'establishment',
#  'clothing_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'doctor',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'cafe',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'lodging',
#  'point_of_interest',
#  'establishment',
#  'lodging',
#  'point_of_interest',
#  'establishment',
#  'jewelry_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'convenience_store',
#  'cafe',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'convenience_store',
#  'bakery',
#  'cafe',
#  'liquor_store',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'cafe',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'gas_station',
#  'point_of_interest',
#  'establishment',
#  'transit_station',
#  'point_of_interest',
#  'establishment',
#  'shoe_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'general_contractor',
#  'real_estate_agency',
#  'point_of_interest',
#  'establishment',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'bar',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'bar',
#  'point_of_interest',
#  'establishment',
#  'general_contractor',
#  'point_of_interest',
#  'establishment',
#  'church',
#  'place_of_worship',
#  'point_of_interest',
#  'establishment',
#  'bank',
#  'point_of_interest',
#  'establishment',
#  'atm',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'store',
#  'point_of_interest',
#  'establishment',
#  'park',
#  'point_of_interest',
#  'establishment',
#  'park',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'transit_station',
#  'point_of_interest',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'lodging',
#  'point_of_interest',
#  'establishment',
#  'gas_station',
#  'point_of_interest',
#  'establishment',
#  'furniture_store',
#  'home_goods_store',
#  'general_contractor',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'furniture_store',
#  'home_goods_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'atm',
#  'point_of_interest',
#  'establishment',
#  'bank',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'museum',
#  'point_of_interest',
#  'establishment',
#  'courthouse',
#  'point_of_interest',
#  'establishment',
#  'local_government_office',
#  'point_of_interest',
#  'establishment',
#  'local_government_office',
#  'point_of_interest',
#  'establishment',
#  'local_government_office',
#  'point_of_interest',
#  'establishment',
#  'bar',
#  'point_of_interest',
#  'establishment',
#  'jewelry_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'tourist_attraction',
#  'point_of_interest',
#  'establishment',
#  'jewelry_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'clothing_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'meal_takeaway',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'home_goods_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'gas_station',
#  'atm',
#  'car_wash',
#  'convenience_store',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'convenience_store',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'convenience_store',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'convenience_store',
#  'cafe',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'convenience_store',
#  'cafe',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'doctor',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'doctor',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'doctor',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'finance',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'cafe',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'hair_care',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'beauty_salon',
#  'point_of_interest',
#  'establishment',
#  'hair_care',
#  'point_of_interest',
#  'establishment',
#  'spa',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'veterinary_care',
#  'point_of_interest',
#  'establishment',
#  'transit_station',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'clothing_store',
#  'store',
#  'establishment',
#  'finance',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'painter',
#  'electrician',
#  'plumber',
#  'general_contractor',
#  'point_of_interest',
#  'establishment',
#  'hardware_store',
#  'furniture_store',
#  'home_goods_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'health',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'gas_station',
#  'point_of_interest',
#  'establishment',
#  'hair_care',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'atm',
#  'point_of_interest',
#  'establishment',
#  'doctor',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'general_contractor',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'night_club',
#  'bar',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'lodging',
#  'point_of_interest',
#  'establishment',
#  'cafe',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'meal_takeaway',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'cafe',
#  'bakery',
#  'meal_takeaway',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'gas_station',
#  'convenience_store',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'parking',
#  'premise',
#  'point_of_interest',
#  'establishment',
#  'transit_station',
#  'point_of_interest',
#  'establishment',
#  'transit_station',
#  'point_of_interest',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'physiotherapist',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'physiotherapist',
#  'doctor',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'physiotherapist',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'grocery_or_supermarket',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'finance',
#  'point_of_interest',
#  'establishment',
#  'finance',
#  'point_of_interest',
#  'establishment',
#  'finance',
#  'point_of_interest',
#  'establishment',
#  'locksmith',
#  'point_of_interest',
#  'establishment',
#  'spa',
#  'point_of_interest',
#  'establishment',
#  'beauty_salon',
#  'point_of_interest',
#  'establishment',
#  'finance',
#  'point_of_interest',
#  'establishment',
#  'beauty_salon',
#  'point_of_interest',
#  'establishment',
#  'hair_care',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'bar',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'lawyer',
#  'point_of_interest',
#  'establishment',
#  'lawyer',
#  'point_of_interest',
#  'establishment',
#  'atm',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'liquor_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'liquor_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'meal_delivery',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'meal_takeaway',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'finance',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'jewelry_store',
#  'finance',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'transit_station',
#  'point_of_interest',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'meal_takeaway',
#  'bar',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'electronics_store',
#  'home_goods_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'car_repair',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'transit_station',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'gym',
#  'spa',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'electronics_store',
#  'home_goods_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'electronics_store',
#  'home_goods_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'beauty_salon',
#  'hair_care',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'car_wash',
#  'point_of_interest',
#  'establishment',
#  'car_repair',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'car_repair',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'electronics_store',
#  'car_repair',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'atm',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'liquor_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'liquor_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'university',
#  'point_of_interest',
#  'establishment',
#  'doctor',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'doctor',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'finance',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'bank',
#  'atm',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'transit_station',
#  'point_of_interest',
#  'establishment',
#  'transit_station',
#  'point_of_interest',
#  'establishment',
#  'electronics_store',
#  'home_goods_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'bakery',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'school',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'electronics_store',
#  'home_goods_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'bakery',
#  'meal_takeaway',
#  'cafe',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'car_wash',
#  'point_of_interest',
#  'establishment',
#  'car_wash',
#  'point_of_interest',
#  'establishment',
#  'car_wash',
#  'point_of_interest',
#  'establishment',
#  'spa',
#  'point_of_interest',
#  'establishment',
#  'lodging',
#  'point_of_interest',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'bar',
#  'point_of_interest',
#  'establishment',
#  'bar',
#  'point_of_interest',
#  'establishment',
#  'shopping_mall',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'school',
#  'point_of_interest',
#  'establishment',
#  'finance',
#  'point_of_interest',
#  'establishment',
#  'atm',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'electronics_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'bar',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'general_contractor',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'gym',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'dentist',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'furniture_store',
#  'home_goods_store',
#  'general_contractor',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'hardware_store',
#  'furniture_store',
#  'home_goods_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'convenience_store',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'bar',
#  'point_of_interest',
#  'establishment',
#  'insurance_agency',
#  'point_of_interest',
#  'establishment',
#  'real_estate_agency',
#  'point_of_interest',
#  'establishment',
#  'real_estate_agency',
#  'point_of_interest',
#  'establishment',
#  'real_estate_agency',
#  'point_of_interest',
#  'establishment',
#  'real_estate_agency',
#  'point_of_interest',
#  'establishment',
#  'grocery_or_supermarket',
#  'florist',
#  'supermarket',
#  'liquor_store',
#  'food',
#  'health',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'furniture_store',
#  'home_goods_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'clothing_store',
#  'store',
#  'establishment',
#  'florist',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'laundry',
#  'home_goods_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'general_contractor',
#  'point_of_interest',
#  'establishment',
#  'plumber',
#  'point_of_interest',
#  'establishment',
#  'lawyer',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'grocery_or_supermarket',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'home_goods_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'transit_station',
#  'point_of_interest',
#  'establishment',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'tourist_attraction',
#  'point_of_interest',
#  'establishment',
#  'transit_station',
#  'point_of_interest',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'parking',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'beauty_salon',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'clothing_store',
#  'store',
#  'establishment',
#  'insurance_agency',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'cafe',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'home_goods_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'library',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'car_repair',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'plumber',
#  'general_contractor',
#  'point_of_interest',
#  'establishment',
#  'cafe',
#  'food',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'meal_delivery',
#  'meal_takeaway',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'bar',
#  'restaurant',
#  'food',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'electronics_store',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'primary_school',
#  'school',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'health',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'bank',
#  'atm',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'store',
#  'establishment',
#  'transit_station',
#  'point_of_interest',
#  'establishment',
#  'transit_station',
#  'point_of_interest',
#  'establishment',
#  'university',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'point_of_interest',
#  'establishment',
#  'lodging',
#  'point_of_interest',
#  'establishment',
#  ...]

# %%
types_counts = Counter(types_list_flat)

# %%
types_counts_df = pd.DataFrame(list(types_counts.items()),columns = ['type','count'])

# %%
types_counts_df = types_counts_df[types_counts_df['type'] != 'point_of_interest']
types_counts_df = types_counts_df[types_counts_df['type'] != 'establishment']
types_counts_df = types_counts_df[types_counts_df['type'] != 'store']
types_counts_df = types_counts_df[types_counts_df['type'] != 'health']
types_counts_df = types_counts_df[types_counts_df['type'] != 'food']
types_counts_df = types_counts_df[types_counts_df['type'] != 'premise']

# %%
types_counts_df = types_counts_df.sort_values(by = 'count')

# %% [markdown]
# 'aquarium', 'city_hall', 'natural_feature', 'hindu_temple',
#        'synagogue', 'train_station', 'mosque', 'airport',
#        'amusement_park', 'stadium', 'bowling_alley', 'zoo', 'campground',
#        'bicycle_store', 'rv_park', 'movie_theater', 'fire_station',
#        'courthouse', 'library', 'car_rental', 'post_office', 'police',
#        'funeral_home', 'pet_store', 'department_store', 'museum',
#        'drugstore', 'art_gallery', 'book_store', 'locksmith', 'florist',
#        'secondary_school', 'painter', 'movie_rental', 'plumber',
#        'electrician', 'primary_school', 'hardware_store',
#        'veterinary_care', 'roofing_contractor', 'university', 'hospital',
#        'cemetery', 'supermarket', 'physiotherapist', 'premise',
#        'jewelry_store', 'shopping_mall', 'car_wash', 'travel_agency',
#        'night_club', 'bus_station', 'shoe_store', 'spa', 'moving_company',
#        'laundry', 'accounting', 'tourist_attraction', 'storage',
#        'liquor_store', 'pharmacy', 'bank', 'parking', 'meal_delivery',
#        'bakery', 'lawyer', 'local_government_office', 'park', 'gym',
#        'insurance_agency', 'real_estate_agency', 'car_dealer', 'dentist',
#        'furniture_store', 'lodging', 'grocery_or_supermarket', 'cafe',
#        'convenience_store', 'school', 'electronics_store', 'gas_station',
#        'church', 'beauty_salon', 'clothing_store', 'place_of_worship',
#        'meal_takeaway', 'hair_care', 'doctor', 'car_repair', 'bar', 'atm',
#        'general_contractor', 'home_goods_store', 'transit_station',
#        'finance', 'restaurant', 'health', 'food', 'store'

# %%
types_counts_df.head(10)
# Out:
#                 type  count
# 100         aquarium      1
# 85         city_hall      1
# 88   natural_feature      1
# 98      hindu_temple      2
# 97         synagogue      2
# 91     train_station      2
# 76            mosque      3
# 96           airport      3
# 87    amusement_park      5
# 84           stadium      6

# %%
types_counts_df.tail(10)
# Out:
#                   type  count               parent_type
# 5            hair_care    519                Beauty_Spa
# 10              doctor    659                    Health
# 51          car_repair    714              Car_Services
# 1                  bar    738             Entertainment
# 26                 atm    759              Bank_Finance
# 21  general_contractor    802  Construction_or_Services
# 36             finance    920              Bank_Finance
# 29    home_goods_store    955                     Store
# 19     transit_station   1107            Transportation
# 8           restaurant   1944           Food_Restaurant

# %%
types_counts_df.tail(10).plot(x = 'type', kind = 'bar', fontsize = 13, figsize = (12,6))

# %%
parent_dict = {'Education':['secondary_school', 'university', 'school', 'primary_school'],
               'Food_Restaurant': ['supermarket','restaurant','meal_delivery', 'grocery_or_supermarket','cafe','meal_takeaway','bakery', 'liquor_store'],
               'Lodging': ['rv_park', 'lodging'],
               'Health': ['drugstore','veterinary_care', 'hospital', 'physiotherapist', 'doctor', 'pharmacy', 'dentist', 'gym'],
               'Religious': ['hindu_temple', 'synagogue', 'mosque', 'church', 'place_of_worship'],
               'Construction_or_Services': ['locksmith', 'florist', 'painter', 'plumber', 'electrician', 'roofing_contractor','moving_company','general_contractor', 'insurance_agency','real_estate_agency', 'lawyer', 'laundry', 'storage'],
               'Transportation': ['train_station', 'airport', 'car_rental','bus_station', 'transit_station', 'parking'],
               'Entertainment': ['night_club', 'bar','aquarium', 'amusement_park', 'stadium', 'bowling_alley', 'zoo', 'movie_theater', 'museum', 'art_gallery', 'movie_rental', 'tourist_attraction', 'travel_agency'],
               'Government': ['city_hall', 'fire_station', 'courthouse', 'library', 'post_office', 'police', 'local_government_office'],
               'Store': ['bicycle_store', 'pet_store', 'department_store', 'book_store', 'hardware_store','jewelry_store', 'shopping_mall', 'furniture_store', 'electronics_store', 'clothing_store','shoe_store', 'home_goods_store'],
               'Gas_Station': ['convenience_store', 'gas_station'],
               'Nature': ['natural_feature', 'campground', 'park'],
               'Beauty_Spa': ['spa', 'hair_care', 'beauty_salon'],
               'Bank_Finance': ['accounting', 'bank', 'atm', 'finance'],
               'Funeral': ['funeral_home','cemetery'],
               'Car_Services': ['car_dealer','car_repair','car_wash']}

# %%
types_counts_df['parent_type'] = ''

# %%
for index, row in types_counts_df.iterrows():
    for key in parent_dict:
        if row.isin(parent_dict[key]).any():
            types_counts_df['parent_type'][index] = key
# Out:
# C:\Users\savro\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
types_counts_df.head(20)
# Out:
#                 type  count     parent_type
# 100         aquarium      1   Entertainment
# 85         city_hall      1      Government
# 88   natural_feature      1          Nature
# 98      hindu_temple      2       Religious
# 97         synagogue      2       Religious
# 91     train_station      2  Transportation
# 76            mosque      3       Religious
# 96           airport      3  Transportation
# 87    amusement_park      5   Entertainment
# 84           stadium      6   Entertainment
# 89               zoo      7   Entertainment
# 92     bowling_alley      7   Entertainment
# 99     bicycle_store      8           Store
# 93        campground      8          Nature
# 86           rv_park      9         Lodging
# 94     movie_theater     16   Entertainment
# 80      fire_station     16      Government
# 31        courthouse     18      Government
# 61           library     20      Government
# 83        car_rental     23  Transportation

# %%
px.treemap(types_counts_df, 
           path=['parent_type','type'], 
           values = 'count',
           color='count', color_continuous_scale='Peach')
# Out:
# <div>                            <div id="e0a672a8-5d28-4985-a744-2ae55a042ef0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0a672a8-5d28-4985-a744-2ae55a042ef0")) {                    Plotly.newPlot(                        "e0a672a8-5d28-4985-a744-2ae55a042ef0",                        [{"branchvalues": "total", "customdata": [[151.0], [3.0], [5.0], [1.0], [40.0], [759.0], [198.0], [178.0], [738.0], [487.0], [8.0], [47.0], [7.0], [134.0], [360.0], [8.0], [271.0], [23.0], [714.0], [115.0], [82.0], [467.0], [1.0], [497.0], [418.0], [18.0], [274.0], [33.0], [659.0], [38.0], [62.0], [441.0], [920.0], [16.0], [53.0], [26.0], [303.0], [466.0], [802.0], [356.0], [246.0], [519.0], [67.0], [2.0], [955.0], [76.0], [248.0], [104.0], [146.0], [201.0], [20.0], [175.0], [221.0], [49.0], [336.0], [190.0], [504.0], [3.0], [58.0], [16.0], [146.0], [37.0], [1.0], [130.0], [57.0], [238.0], [184.0], [28.0], [176.0], [96.0], [502.0], [61.0], [25.0], [23.0], [97.0], [64.0], [263.0], [1944.0], [70.0], [9.0], [430.0], [56.0], [142.0], [105.0], [145.0], [6.0], [159.0], [87.0], [2.0], [156.0], [2.0], [1107.0], [116.0], [72.0], [67.0], [7.0], [97.0], [735.5408366533865], [458.3449174630756], [542.2381818181818], [389.777729823047], [317.2282958199357], [460.20121488230825], [1154.4273728369167], [68.51851851851852], [443.3031674208145], [157.33333333333334], [380.9889705882353], [327.4695652173913], [229.59109311740892], [481.6700819672131], [547.9721611721611], [879.4239504473503]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>count_sum=%{value}<br>parent=%{parent}<br>id=%{id}<br>count=%{color}<extra></extra>", "ids": ["Bank_Finance/accounting", "Transportation/airport", "Entertainment/amusement_park", "Entertainment/aquarium", "Entertainment/art_gallery", "Bank_Finance/atm", "Food_Restaurant/bakery", "Bank_Finance/bank", "Entertainment/bar", "Beauty_Spa/beauty_salon", "Store/bicycle_store", "Store/book_store", "Entertainment/bowling_alley", "Transportation/bus_station", "Food_Restaurant/cafe", "Nature/campground", "Car_Services/car_dealer", "Transportation/car_rental", "Car_Services/car_repair", "Car_Services/car_wash", "Funeral/cemetery", "Religious/church", "Government/city_hall", "Store/clothing_store", "Gas_Station/convenience_store", "Government/courthouse", "Health/dentist", "Store/department_store", "Health/doctor", "Health/drugstore", "Construction_or_Services/electrician", "Store/electronics_store", "Bank_Finance/finance", "Government/fire_station", "Construction_or_Services/florist", "Funeral/funeral_home", "Store/furniture_store", "Gas_Station/gas_station", "Construction_or_Services/general_contractor", "Food_Restaurant/grocery_or_supermarket", "Health/gym", "Beauty_Spa/hair_care", "Store/hardware_store", "Religious/hindu_temple", "Store/home_goods_store", "Health/hospital", "Construction_or_Services/insurance_agency", "Store/jewelry_store", "Construction_or_Services/laundry", "Construction_or_Services/lawyer", "Government/library", "Food_Restaurant/liquor_store", "Government/local_government_office", "Construction_or_Services/locksmith", "Lodging/lodging", "Food_Restaurant/meal_delivery", "Food_Restaurant/meal_takeaway", "Religious/mosque", "Entertainment/movie_rental", "Entertainment/movie_theater", "Construction_or_Services/moving_company", "Entertainment/museum", "Nature/natural_feature", "Entertainment/night_club", "Construction_or_Services/painter", "Nature/park", "Transportation/parking", "Store/pet_store", "Health/pharmacy", "Health/physiotherapist", "Religious/place_of_worship", "Construction_or_Services/plumber", "Government/police", "Government/post_office", "/premise", "Education/primary_school", "Construction_or_Services/real_estate_agency", "Food_Rest ...
